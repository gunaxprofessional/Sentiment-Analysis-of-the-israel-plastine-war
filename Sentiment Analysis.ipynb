# %%
# !pip install -q vaderSentiment pymongo spacy

# %%
'''
Importing necessary libraries:
The code imports libraries for web scraping, regular expressions, MongoDB, spaCy for NER (Named Entity Recognition), 
displacy for visualization, and VADER SentimentIntensityAnalyzer for sentiment analysis.
'''
from bs4 import BeautifulSoup
import requests
import re
import pymongo
import spacy
from spacy import displacy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#Downloading spaCy model
# !python -q -m spacy download en_core_web_lg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting en-core-web-lg==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.7.0/en_core_web_lg-3.7.0-py3-none-any.whl (587.7 MB)
#      -------------------------------------- 587.7/587.7 MB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from en-core-web-lg==3.7.0) (3.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.0.10)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (4.64.1)
# Requirement already satisfied: jinja2 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.4.8)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (63.4.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.10.7)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.28.1)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.9.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.0.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.1.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (8.2.1)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.3.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.0.10)
# Requirement already satisfied: numpy>=1.19.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.0.9)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (4.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (1.26.11)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.1.3)
# Requirement already satisfied: colorama in c:\users\guna0\appdata\roaming\python\python39\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\guna0\appdata\roaming\python\python39\site-packages (from jinja2->spacy<3.8.0,>=3.7.0->en-core-web-lg==3.7.0) (2.1.3)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
#Initializing NER and Sentiment Analyzer:
analyzer = SentimentIntensityAnalyzer()
NER = spacy.load("en_core_web_lg")

# %%
'''
Fetching and Preprocessing the Article:

The code fetches the HTML content of a given URL using requests and parses it using BeautifulSoup.
The main content of the HTML is extracted and converted to lowercase.
Some basic data preprocessing is performed, including removing extra whitespaces, text within square brackets, 
text within parentheses, and special characters using regular expressions.
'''

# %%
URL = "https://www.bbc.com/news/newsbeat-44124396"

# %%
html_content = requests.get(URL).text

# %%
soup = BeautifulSoup(html_content, "lxml")

# %%
# Extract the main content from the HTML
body = soup.body.text

# %%
# Convert text to lowercase
body = body.lower()

# %%
body[:1000]
# Out:
# 'bbc homepageskip to contentaccessibility helpyour accounthomenewssportearthreelworklifetravelmore menumore menusearch bbchomenewssportearthreelworklifetravelculturefuturemusictvweathersoundsclose menubbc newsmenuhomeisrael-gaza warwar in ukraineclimatevideoworldasiaukbusinesstechmorescienceentertainment & artshealthworld news tvin picturesbbc verifynewsbeatworldafricaaustraliaeuropelatin americamiddle eastus & canadaisrael gaza war: history of the conflict explainedpublished4 days agoshareclose panelshare pagecopy linkabout sharingrelated topicsisrael-gaza warimage source, getty imagesthe palestinian militant group hamas launched an unprecedented assault on israel on 7 october, with hundreds of gunmen infiltrating communities near the gaza strip.more than 1,400 israelis were killed, while the israeli military says 230 soldiers and civilians, including women and children, were taken to gaza as hostages.more than 8,000 palestinians in gaza have been killed in air and artillery strikes ca'

# %%
len(body)
# Out:
# 13614

# %%
# Data preprocessing steps
cleaned_text = re.sub(r'\s+', ' ', body)  # Remove extra whitespaces
cleaned_text = re.sub(r'\[.*?\]', '', body)  # Remove text within square brackets
cleaned_text = re.sub(r'\(.*?\)', '', body)  # Remove text within parentheses
cleaned_text = re.sub(r'[^A-Za-z0-9\s]', '', cleaned_text) # Remove special characters using regular expressions

# %%
cleaned_text[:1000]
# Out:
# 'bbc homepageskip to contentaccessibility helpyour accounthomenewssportearthreelworklifetravelmore menumore menusearch bbchomenewssportearthreelworklifetravelculturefuturemusictvweathersoundsclose menubbc newsmenuhomeisraelgaza warwar in ukraineclimatevideoworldasiaukbusinesstechmorescienceentertainment  artshealthworld news tvin picturesbbc verifynewsbeatworldafricaaustraliaeuropelatin americamiddle eastus  canadaisrael gaza war history of the conflict explainedpublished4 days agoshareclose panelshare pagecopy linkabout sharingrelated topicsisraelgaza warimage source getty imagesthe palestinian militant group hamas launched an unprecedented assault on israel on 7 october with hundreds of gunmen infiltrating communities near the gaza stripmore than 1400 israelis were killed while the israeli military says 230 soldiers and civilians including women and children were taken to gaza as hostagesmore than 8000 palestinians in gaza have been killed in air and artillery strikes carried out by t'

# %%
len(cleaned_text)
# Out:
# 13278

# %%
# Apply NER to the text
doc = NER(cleaned_text)

# %%
# Iterate through the entities and display them with their labels
for ent in doc.ents[:10]:
    print(f"Entity: {ent.text}, Label: {ent.label_}")
# Out:
# Entity: bbc homepageskip, Label: PERSON
# Entity: contentaccessibility helpyour, Label: ORG
# Entity: menusearch bbchomenewssportearthreelworklifetravelculturefuturemusictvweathersoundsclose, Label: PERSON
# Entity: menubbc newsmenuhomeisraelgaza warwar, Label: ORG
# Entity: artshealthworld news, Label: ORG
# Entity: tvin picturesbbc, Label: PERSON
# Entity: verifynewsbeatworldafricaaustraliaeuropelatin americamiddle eastus  , Label: PERSON
# Entity: canadaisrael gaza war, Label: ORG
# Entity: explainedpublished4 days, Label: DATE
# Entity: agoshareclose panelshare pagecopy linkabout sharingrelated, Label: PERSON

# %%
# Visualize the NER results using displacy
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bbc homepageskip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     contentaccessibility helpyour
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  accounthomenewssportearthreelworklifetravelmore menumore
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     menusearch bbchomenewssportearthreelworklifetravelculturefuturemusictvweathersoundsclose
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     menubbc newsmenuhomeisraelgaza warwar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in ukraineclimatevideoworldasiaukbusinesstechmorescienceentertainment
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     artshealthworld news
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tvin picturesbbc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     verifynewsbeatworldafricaaustraliaeuropelatin americamiddle eastus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     canadaisrael gaza war
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  history of the conflict
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     explainedpublished4 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     agoshareclose panelshare pagecopy linkabout sharingrelated
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  topicsisraelgaza warimage source getty imagesthe
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palestinian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  militant group
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hamas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  launched an unprecedented assault on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     israel
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     7 october
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  with
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of gunmen infiltrating communities near
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the gaza stripmore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  than
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     israelis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  were killed while the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     israeli
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  military says
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     230
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  soldiers and civilians including women and children were taken to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gaza
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hostagesmore than 8000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     palestinians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gaza
#     <span style="font-size: 0.8em; f

# %%
#MongoDB Connection:

from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017/")
db = client["ner_db"]
collection = db["ner_results"]

# %%
#checking whether a mongodb server is running or not.
try:
    client = MongoClient('localhost', 27017)
    db = client.admin
    server_info = db.command("serverStatus")
    print("MongoDB is running.")
except Exception as e:
    print("MongoDB is not running or cannot be reached.")
# Out:
# MongoDB is running.

# %%
#Storing NER Results in MongoDB:
ner_results = []
for ent in doc.ents:
    entity_data = {
        "text": ent.text,
        "label": ent.label_,
        "start_char": ent.start_char,
        "end_char": ent.end_char,
    }
    ner_results.append(entity_data)

# %%
collection.insert_many(ner_results)

# %%
# Find all documents
all_documents = collection.find()
print("\nAll documents:")
for document in all_documents:
    print(document)
# Out:
# All documents:
# {'_id': ObjectId('6543b8ba3392dda60644c3b7'), 'text': 'BBC HomepageSkip', 'label': 'ORG', 'start_char': 0, 'end_char': 16}
# {'_id': ObjectId('6543b8ba3392dda60644c3b8'), 'text': 'menuSearch', 'label': 'PERSON', 'start_char': 107, 'end_char': 117}
# {'_id': ObjectId('6543b8ba3392dda60644c3b9'), 'text': 'ArtsHealthWorld News', 'label': 'ORG', 'start_char': 307, 'end_char': 327}
# {'_id': ObjectId('6543b8ba3392dda60644c3ba'), 'text': 'VerifyNewsbeatWorldAfricaAustraliaEuropeLatin AmericaMiddle', 'label': 'ORG', 'start_char': 345, 'end_char': 404}
# {'_id': ObjectId('6543b8ba3392dda60644c3bb'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 427, 'end_char': 431}
# {'_id': ObjectId('6543b8ba3392dda60644c3bc'), 'text': 'agoShareclose panelShare', 'label': 'PERSON', 'start_char': 486, 'end_char': 510}
# {'_id': ObjectId('6543b8ba3392dda60644c3bd'), 'text': 'Getty', 'label': 'ORG', 'start_char': 580, 'end_char': 585}
# {'_id': ObjectId('6543b8ba3392dda60644c3be'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 596, 'end_char': 607}
# {'_id': ObjectId('6543b8ba3392dda60644c3bf'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 623, 'end_char': 628}
# {'_id': ObjectId('6543b8ba3392dda60644c3c0'), 'text': 'Israel', 'label': 'GPE', 'start_char': 666, 'end_char': 672}
# {'_id': ObjectId('6543b8ba3392dda60644c3c1'), 'text': '7 October', 'label': 'DATE', 'start_char': 676, 'end_char': 685}
# {'_id': ObjectId('6543b8ba3392dda60644c3c2'), 'text': 'hundreds', 'label': 'CARDINAL', 'start_char': 692, 'end_char': 700}
# {'_id': ObjectId('6543b8ba3392dda60644c3c3'), 'text': 'the Gaza Strip', 'label': 'GPE', 'start_char': 741, 'end_char': 755}
# {'_id': ObjectId('6543b8ba3392dda60644c3c4'), 'text': 'More than 1,400', 'label': 'CARDINAL', 'start_char': 756, 'end_char': 771}
# {'_id': ObjectId('6543b8ba3392dda60644c3c5'), 'text': 'Israelis', 'label': 'NORP', 'start_char': 772, 'end_char': 780}
# {'_id': ObjectId('6543b8ba3392dda60644c3c6'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 804, 'end_char': 811}
# {'_id': ObjectId('6543b8ba3392dda60644c3c7'), 'text': '230', 'label': 'CARDINAL', 'start_char': 826, 'end_char': 829}
# {'_id': ObjectId('6543b8ba3392dda60644c3c8'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 898, 'end_char': 902}
# {'_id': ObjectId('6543b8ba3392dda60644c3c9'), 'text': 'More than 8,000', 'label': 'CARDINAL', 'start_char': 915, 'end_char': 930}
# {'_id': ObjectId('6543b8ba3392dda60644c3ca'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 931, 'end_char': 943}
# {'_id': ObjectId('6543b8ba3392dda60644c3cb'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 947, 'end_char': 951}
# {'_id': ObjectId('6543b8ba3392dda60644c3cc'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 1017, 'end_char': 1024}
# {'_id': ObjectId('6543b8ba3392dda60644c3cd'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 1064, 'end_char': 1069}
# {'_id': ObjectId('6543b8ba3392dda60644c3ce'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 1093, 'end_char': 1097}
# {'_id': ObjectId('6543b8ba3392dda60644c3cf'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 1099, 'end_char': 1106}
# {'_id': ObjectId('6543b8ba3392dda60644c3d0'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 1141, 'end_char': 1145}
# {'_id': ObjectId('6543b8ba3392dda60644c3d1'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 1159, 'end_char': 1171}
# {'_id': ObjectId('6543b8ba3392dda60644c3d2'), 'text': 'Israel', 'label': 'GPE', 'start_char': 1225, 'end_char': 1231}
# {'_id': ObjectId('6543b8ba3392dda60644c3d3'), 'text': 'several dozen', 'label': 'CARDINAL', 'start_char': 1345, 'end_char': 1358}
# {'_id': ObjectId('6543b8ba3392dda60644c3d4'), 'text': 'Egypt', 'label': 'GPE', 'start_char': 1379, 'end_char': 1384}
# {'_id': ObjectId('6543b8ba3392dda60644c3d5'), 'text': 'Rafah', 'label': 'GPE', 'start_char': 1387, 'end_char': 1392}
# {'_id': ObjectId('6543b8ba3392dda60644c3d6'), 'text': 'Saturday', 'label': 'DATE', 'start_char': 1408, 'end_char': 1416}
# {'_id': ObjectId('6543b8ba3392dda60644c3d7'), 'text': 'Israel', 'label': 'GPE', 'start_char': 1425, 'end_char': 1431}
# {'_id': ObjectId('6543b8ba3392dda60644c3d8'), 'text': 'Kibbutz', 'label': 'GPE', 'start_char': 1519, 'end_char': 1526}
# {'_id': ObjectId('6543b8ba3392dda60644c3d9'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 1545, 'end_char': 1549}
# {'_id': ObjectId('6543b8ba3392dda60644c3da'), 'text': 'Israel', 'label': 'GPE', 'start_char': 1638, 'end_char': 1644}
# {'_id': ObjectId('6543b8ba3392dda60644c3db'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 1649, 'end_char': 1653}
# {'_id': ObjectId('6543b8ba3392dda60644c3dc'), 'text': 'now?History', 'label': 'ORG', 'start_char': 1663, 'end_char': 1674}
# {'_id': ObjectId('6543b8ba3392dda60644c3dd'), 'text': 'Israel', 'label': 'GPE', 'start_char': 1697, 'end_char': 1703}
# {'_id': ObjectId('6543b8ba3392dda60644c3de'), 'text': 'Israel', 'label': 'GPE', 'start_char': 1733, 'end_char': 1739}
# {'_id': ObjectId('6543b8ba3392dda60644c3df'), 'text': '1948', 'label': 'DATE', 'start_char': 1747, 'end_char': 1751}
# {'_id': ObjectId('6543b8ba3392dda60644c3e0'), 'text': 'the Balfour Declaration?Britain', 'label': 'EVENT', 'start_char': 1766, 'end_char': 1797}
# {'_id': ObjectId('6543b8ba3392dda60644c3e1'), 'text': 'Palestine', 'label': 'GPE', 'start_char': 1832, 'end_char': 1841}
# {'_id': ObjectId('6543b8ba3392dda60644c3e2'), 'text': 'the Ottoman Empire', 'label': 'GPE', 'start_char': 1866, 'end_char': 1884}
# {'_id': ObjectId('6543b8ba3392dda60644c3e3'), 'text': 'the Middle East', 'label': 'LOC', 'start_char': 1911, 'end_char': 1926}
# {'_id': ObjectId('6543b8ba3392dda60644c3e4'), 'text': 'World War One', 'label': 'EVENT', 'start_char': 1931, 'end_char': 1944}
# {'_id': ObjectId('6543b8ba3392dda60644c3e5'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 1974, 'end_char': 1980}
# {'_id': ObjectId('6543b8ba3392dda60644c3e6'), 'text': 'Arab', 'label': 'NORP', 'start_char': 1994, 'end_char': 1998}
# {'_id': ObjectId('6543b8ba3392dda60644c3e7'), 'text': 'two', 'label': 'CARDINAL', 'start_char': 2071, 'end_char': 2074}
# {'_id': ObjectId('6543b8ba3392dda60644c3e8'), 'text': 'UK', 'label': 'GPE', 'start_char': 2130, 'end_char': 2132}
# {'_id': ObjectId('6543b8ba3392dda60644c3e9'), 'text': 'Palestine', 'label': 'GPE', 'start_char': 2179, 'end_char': 2188}
# {'_id': ObjectId('6543b8ba3392dda60644c3ea'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 2193, 'end_char': 2199}
# {'_id': ObjectId('6543b8ba3392dda60644c3eb'), 'text': 'the Balfour Declaration of 1917', 'label': 'LAW', 'start_char': 2226, 'end_char': 2257}
# {'_id': ObjectId('6543b8ba3392dda60644c3ec'), 'text': 'Arthur Balfour', 'label': 'PERSON', 'start_char': 2299, 'end_char': 2313}
# {'_id': ObjectId('6543b8ba3392dda60644c3ed'), 'text': 'Britain', 'label': 'GPE', 'start_char': 2317, 'end_char': 2324}
# {'_id': ObjectId('6543b8ba3392dda60644c3ee'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 2327, 'end_char': 2333}
# {'_id': ObjectId('6543b8ba3392dda60644c3ef'), 'text': 'British', 'label': 'NORP', 'start_char': 2381, 'end_char': 2388}
# {'_id': ObjectId('6543b8ba3392dda60644c3f0'), 'text': 'Palestine', 'label': 'GPE', 'start_char': 2402, 'end_char': 2411}
# {'_id': ObjectId('6543b8ba3392dda60644c3f1'), 'text': 'League of Nations', 'label': 'ORG', 'start_char': 2446, 'end_char': 2463}
# {'_id': ObjectId('6543b8ba3392dda60644c3f2'), 'text': 'the United Nations', 'label': 'ORG', 'start_char': 2480, 'end_char': 2498}
# {'_id': ObjectId('6543b8ba3392dda60644c3f3'), 'text': '1922.To', 'label': 'GPE', 'start_char': 2504, 'end_char': 2511}
# {'_id': ObjectId('6543b8ba3392dda60644c3f4'), 'text': 'Jews', 'label': 'NORP', 'start_char': 2512, 'end_char': 2516}
# {'_id': ObjectId('6543b8ba3392dda60644c3f5'), 'text': 'Palestine', 'label': 'GPE', 'start_char': 2517, 'end_char': 2526}
# {'_id': ObjectId('6543b8ba3392dda60644c3f6'), 'text': 'Palestinian Arabs', 'label': 'NORP', 'start_char': 2557, 'end_char': 2574}
# {'_id': ObjectId('6543b8ba3392dda60644c3f7'), 'text': 'Getty ImagesImage', 'label': 'ORG', 'start_char': 2632, 'end_char': 2649}
# {'_id': ObjectId('6543b8ba3392dda60644c3f8'), 'text': 'Haganah', 'label': 'NORP', 'start_char': 2661, 'end_char': 2668}
# {'_id': ObjectId('6543b8ba3392dda60644c3f9'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 2670, 'end_char': 2676}
# {'_id': ObjectId('6543b8ba3392dda60644c3fa'), 'text': 'the Israeli War of Independence', 'label': 'EVENT', 'start_char': 2723, 'end_char': 2754}
# {'_id': ObjectId('6543b8ba3392dda60644c3fb'), 'text': '1948Between the 1920s and', 'label': 'DATE', 'start_char': 2755, 'end_char': 2780}
# {'_id': ObjectId('6543b8ba3392dda60644c3fc'), 'text': '1940s', 'label': 'DATE', 'start_char': 2781, 'end_char': 2786}
# {'_id': ObjectId('6543b8ba3392dda60644c3fd'), 'text': 'Jews', 'label': 'NORP', 'start_char': 2802, 'end_char': 2806}
# {'_id': ObjectId('6543b8ba3392dda60644c3fe'), 'text': 'Europe', 'label': 'LOC', 'start_char': 2866, 'end_char': 2872}
# {'_id': ObjectId('6543b8ba3392dda60644c3ff'), 'text': 'the Nazi', 'label': 'EVENT', 'start_char': 2885, 'end_char': 2893}
# {'_id': ObjectId('6543b8ba3392dda60644c400'), 'text': 'Holocaust in World War Two', 'label': 'EVENT', 'start_char': 2894, 'end_char': 2920}
# {'_id': ObjectId('6543b8ba3392dda60644c401'), 'text': 'Jews', 'label': 'NORP', 'start_char': 2938, 'end_char': 2942}
# {'_id': ObjectId('6543b8ba3392dda60644c402'), 'text': 'Arabs', 'label': 'NORP', 'start_char': 2947, 'end_char': 2952}
# {'_id': ObjectId('6543b8ba3392dda60644c403'), 'text': 'British', 'label': 'NORP', 'start_char': 2966, 'end_char': 2973}
# {'_id': ObjectId('6543b8ba3392dda60644c404'), 'text': '1947', 'label': 'DATE', 'start_char': 2998, 'end_char': 3002}
# {'_id': ObjectId('6543b8ba3392dda60644c405'), 'text': 'UN', 'label': 'ORG', 'start_char': 3008, 'end_char': 3010}
# {'_id': ObjectId('6543b8ba3392dda60644c406'), 'text': 'Palestine', 'label': 'GPE', 'start_char': 3021, 'end_char': 3030}
# {'_id': ObjectId('6543b8ba3392dda60644c407'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 3057, 'end_char': 3063}
# {'_id': ObjectId('6543b8ba3392dda60644c408'), 'text': 'Arab', 'label': 'NORP', 'start_char': 3068, 'end_char': 3072}
# {'_id': ObjectId('6543b8ba3392dda60644c409'), 'text': 'Jerusalem', 'label': 'GPE', 'start_char': 3086, 'end_char': 3095}
# {'_id': ObjectId('6543b8ba3392dda60644c40a'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 3154, 'end_char': 3160}
# {'_id': ObjectId('6543b8ba3392dda60644c40b'), 'text': 'Arab', 'label': 'NORP', 'start_char': 3189, 'end_char': 3193}
# {'_id': ObjectId('6543b8ba3392dda60644c40c'), 'text': 'Getty ImagesImage', 'label': 'ORG', 'start_char': 3235, 'end_char': 3252}
# {'_id': ObjectId('6543b8ba3392dda60644c40d'), 'text': 'Arab Legion', 'label': 'ORG', 'start_char': 3285, 'end_char': 3296}
# {'_id': ObjectId('6543b8ba3392dda60644c40e'), 'text': 'Haganah', 'label': 'NORP', 'start_char': 3328, 'end_char': 3335}
# {'_id': ObjectId('6543b8ba3392dda60644c40f'), 'text': 'the Jewish Agency', 'label': 'ORG', 'start_char': 3337, 'end_char': 3354}
# {'_id': ObjectId('6543b8ba3392dda60644c410'), 'text': 'March', 'label': 'DATE', 'start_char': 3378, 'end_char': 3383}
# {'_id': ObjectId('6543b8ba3392dda60644c411'), 'text': 'Israel', 'label': 'GPE', 'start_char': 3404, 'end_char': 3410}
# {'_id': ObjectId('6543b8ba3392dda60644c412'), 'text': '1948', 'label': 'DATE', 'start_char': 3422, 'end_char': 3426}
# {'_id': ObjectId('6543b8ba3392dda60644c413'), 'text': 'Britain', 'label': 'GPE', 'start_char': 3457, 'end_char': 3464}
# {'_id': ObjectId('6543b8ba3392dda60644c414'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 3478, 'end_char': 3484}
# {'_id': ObjectId('6543b8ba3392dda60644c415'), 'text': 'the State of Israel', 'label': 'GPE', 'start_char': 3518, 'end_char': 3537}
# {'_id': ObjectId('6543b8ba3392dda60644c416'), 'text': 'Jews', 'label': 'NORP', 'start_char': 3577, 'end_char': 3581}
# {'_id': ObjectId('6543b8ba3392dda60644c417'), 'text': 'Jews', 'label': 'NORP', 'start_char': 3638, 'end_char': 3642}
# {'_id': ObjectId('6543b8ba3392dda60644c418'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 3660, 'end_char': 3666}
# {'_id': ObjectId('6543b8ba3392dda60644c419'), 'text': 'Arab', 'label': 'NORP', 'start_char': 3671, 'end_char': 3675}
# {'_id': ObjectId('6543b8ba3392dda60644c41a'), 'text': 'months', 'label': 'DATE', 'start_char': 3711, 'end_char': 3717}
# {'_id': ObjectId('6543b8ba3392dda60644c41b'), 'text': 'the day', 'label': 'DATE', 'start_char': 3723, 'end_char': 3730}
# {'_id': ObjectId('6543b8ba3392dda60644c41c'), 'text': 'Israel', 'label': 'GPE', 'start_char': 3737, 'end_char': 3743}
# {'_id': ObjectId('6543b8ba3392dda60644c41d'), 'text': 'five', 'label': 'CARDINAL', 'start_char': 3764, 'end_char': 3768}
# {'_id': ObjectId('6543b8ba3392dda60644c41e'), 'text': 'Arab', 'label': 'NORP', 'start_char': 3769, 'end_char': 3773}
# {'_id': ObjectId('6543b8ba3392dda60644c41f'), 'text': 'Hundreds of thousands', 'label': 'CARDINAL', 'start_char': 3793, 'end_char': 3814}
# {'_id': ObjectId('6543b8ba3392dda60644c420'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 3818, 'end_char': 3830}
# {'_id': ObjectId('6543b8ba3392dda60644c421'), 'text': 'Al Nakba', 'label': 'PERSON', 'start_char': 3888, 'end_char': 3896}
# {'_id': ObjectId('6543b8ba3392dda60644c422'), 'text': 'Catastrophe"By', 'label': 'PERSON', 'start_char': 3906, 'end_char': 3920}
# {'_id': ObjectId('6543b8ba3392dda60644c423'), 'text': 'the following year', 'label': 'DATE', 'start_char': 3964, 'end_char': 3982}
# {'_id': ObjectId('6543b8ba3392dda60644c424'), 'text': 'Israel', 'label': 'GPE', 'start_char': 3984, 'end_char': 3990}
# {'_id': ObjectId('6543b8ba3392dda60644c425'), 'text': 'Israel Central Bureau', 'label': 'ORG', 'start_char': 4100, 'end_char': 4121}
# {'_id': ObjectId('6543b8ba3392dda60644c426'), 'text': 'the West Bank', 'label': 'GPE', 'start_char': 4178, 'end_char': 4191}
# {'_id': ObjectId('6543b8ba3392dda60644c427'), 'text': 'Egypt', 'label': 'GPE', 'start_char': 4197, 'end_char': 4202}
# {'_id': ObjectId('6543b8ba3392dda60644c428'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 4212, 'end_char': 4216}
# {'_id': ObjectId('6543b8ba3392dda60644c429'), 'text': 'Jerusalem', 'label': 'GPE', 'start_char': 4218, 'end_char': 4227}
# {'_id': ObjectId('6543b8ba3392dda60644c42a'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 4248, 'end_char': 4255}
# {'_id': ObjectId('6543b8ba3392dda60644c42b'), 'text': 'West', 'label': 'LOC', 'start_char': 4270, 'end_char': 4274}
# {'_id': ObjectId('6543b8ba3392dda60644c42c'), 'text': 'Jordanian', 'label': 'NORP', 'start_char': 4280, 'end_char': 4289}
# {'_id': ObjectId('6543b8ba3392dda60644c42d'), 'text': 'East', 'label': 'LOC', 'start_char': 4304, 'end_char': 4308}
# {'_id': ObjectId('6543b8ba3392dda60644c42e'), 'text': 'the following decades', 'label': 'DATE', 'start_char': 4388, 'end_char': 4409}
# {'_id': ObjectId('6543b8ba3392dda60644c42f'), 'text': 'Israel', 'label': 'GPE', 'start_char': 4410, 'end_char': 4416}
# {'_id': ObjectId('6543b8ba3392dda60644c430'), 'text': 'mapsThe', 'label': 'ORG', 'start_char': 4440, 'end_char': 4447}
# {'_id': ObjectId('6543b8ba3392dda60644c431'), 'text': '1967', 'label': 'DATE', 'start_char': 4473, 'end_char': 4477}
# {'_id': ObjectId('6543b8ba3392dda60644c432'), 'text': 'Israel', 'label': 'GPE', 'start_char': 4479, 'end_char': 4485}
# {'_id': ObjectId('6543b8ba3392dda60644c433'), 'text': 'East Jerusalem', 'label': 'GPE', 'start_char': 4495, 'end_char': 4509}
# {'_id': ObjectId('6543b8ba3392dda60644c434'), 'text': 'the West Bank', 'label': 'GPE', 'start_char': 4514, 'end_char': 4527}
# {'_id': ObjectId('6543b8ba3392dda60644c435'), 'text': 'Syrian', 'label': 'NORP', 'start_char': 4552, 'end_char': 4558}
# {'_id': ObjectId('6543b8ba3392dda60644c436'), 'text': 'Golan Heights', 'label': 'GPE', 'start_char': 4559, 'end_char': 4572}
# {'_id': ObjectId('6543b8ba3392dda60644c437'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 4574, 'end_char': 4578}
# {'_id': ObjectId('6543b8ba3392dda60644c438'), 'text': 'Egyptian', 'label': 'NORP', 'start_char': 4587, 'end_char': 4595}
# {'_id': ObjectId('6543b8ba3392dda60644c439'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 4617, 'end_char': 4628}
# {'_id': ObjectId('6543b8ba3392dda60644c43a'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 4668, 'end_char': 4672}
# {'_id': ObjectId('6543b8ba3392dda60644c43b'), 'text': 'the West Bank', 'label': 'GPE', 'start_char': 4677, 'end_char': 4690}
# {'_id': ObjectId('6543b8ba3392dda60644c43c'), 'text': 'Jordan', 'label': 'GPE', 'start_char': 4719, 'end_char': 4725}
# {'_id': ObjectId('6543b8ba3392dda60644c43d'), 'text': 'Syria', 'label': 'GPE', 'start_char': 4727, 'end_char': 4732}
# {'_id': ObjectId('6543b8ba3392dda60644c43e'), 'text': 'Lebanon', 'label': 'GPE', 'start_char': 4737, 'end_char': 4744}
# {'_id': ObjectId('6543b8ba3392dda60644c43f'), 'text': 'Israel', 'label': 'GPE', 'start_char': 4801, 'end_char': 4807}
# {'_id': ObjectId('6543b8ba3392dda60644c440'), 'text': 'Israel', 'label': 'GPE', 'start_char': 4835, 'end_char': 4841}
# {'_id': ObjectId('6543b8ba3392dda60644c441'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 4912, 'end_char': 4918}
# {'_id': ObjectId('6543b8ba3392dda60644c442'), 'text': 'Getty ImagesImage', 'label': 'ORG', 'start_char': 4939, 'end_char': 4956}
# {'_id': ObjectId('6543b8ba3392dda60644c443'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 4966, 'end_char': 4973}
# {'_id': ObjectId('6543b8ba3392dda60644c444'), 'text': 'East Jerusalem', 'label': 'GPE', 'start_char': 5004, 'end_char': 5018}
# {'_id': ObjectId('6543b8ba3392dda60644c445'), 'text': 'the Six Day War', 'label': 'EVENT', 'start_char': 5026, 'end_char': 5041}
# {'_id': ObjectId('6543b8ba3392dda60644c446'), 'text': '1967Israel', 'label': 'CARDINAL', 'start_char': 5045, 'end_char': 5055}
# {'_id': ObjectId('6543b8ba3392dda60644c447'), 'text': 'the West Bank', 'label': 'GPE', 'start_char': 5071, 'end_char': 5084}
# {'_id': ObjectId('6543b8ba3392dda60644c448'), 'text': 'Jerusalem', 'label': 'GPE', 'start_char': 5109, 'end_char': 5118}
# {'_id': ObjectId('6543b8ba3392dda60644c449'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 5145, 'end_char': 5157}
# {'_id': ObjectId('6543b8ba3392dda60644c44a'), 'text': 'East Jerusalem', 'label': 'GPE', 'start_char': 5164, 'end_char': 5178}
# {'_id': ObjectId('6543b8ba3392dda60644c44b'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 5216, 'end_char': 5227}
# {'_id': ObjectId('6543b8ba3392dda60644c44c'), 'text': 'US', 'label': 'GPE', 'start_char': 5239, 'end_char': 5241}
# {'_id': ObjectId('6543b8ba3392dda60644c44d'), 'text': 'Israel', 'label': 'GPE', 'start_char': 5305, 'end_char': 5311}
# {'_id': ObjectId('6543b8ba3392dda60644c44e'), 'text': 'the past 50 years', 'label': 'DATE', 'start_char': 5325, 'end_char': 5342}
# {'_id': ObjectId('6543b8ba3392dda60644c44f'), 'text': 'Israel', 'label': 'GPE', 'start_char': 5343, 'end_char': 5349}
# {'_id': ObjectId('6543b8ba3392dda60644c450'), 'text': 'the West Bank', 'label': 'GPE', 'start_char': 5375, 'end_char': 5388}
# {'_id': ObjectId('6543b8ba3392dda60644c451'), 'text': 'East Jerusalem', 'label': 'GPE', 'start_char': 5393, 'end_char': 5407}
# {'_id': ObjectId('6543b8ba3392dda60644c452'), 'text': 'more than 700,000', 'label': 'CARDINAL', 'start_char': 5415, 'end_char': 5432}
# {'_id': ObjectId('6543b8ba3392dda60644c453'), 'text': 'Jews', 'label': 'NORP', 'start_char': 5433, 'end_char': 5437}
# {'_id': ObjectId('6543b8ba3392dda60644c454'), 'text': 'the UN Security Council', 'label': 'ORG', 'start_char': 5532, 'end_char': 5555}
# {'_id': ObjectId('6543b8ba3392dda60644c455'), 'text': 'UK', 'label': 'GPE', 'start_char': 5564, 'end_char': 5566}
# {'_id': ObjectId('6543b8ba3392dda60644c456'), 'text': 'Israel', 'label': 'GPE', 'start_char': 5603, 'end_char': 5609}
# {'_id': ObjectId('6543b8ba3392dda60644c457'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 5632, 'end_char': 5644}
# {'_id': ObjectId('6543b8ba3392dda60644c458'), 'text': 'millionSyria0.5 millionSource', 'label': 'PERSON', 'start_char': 5762, 'end_char': 5791}
# {'_id': ObjectId('6543b8ba3392dda60644c459'), 'text': 'Palestinian Central Bureau', 'label': 'ORG', 'start_char': 5793, 'end_char': 5819}
# {'_id': ObjectId('6543b8ba3392dda60644c45a'), 'text': 'StatisticsWhat', 'label': 'ORG', 'start_char': 5823, 'end_char': 5837}
# {'_id': ObjectId('6543b8ba3392dda60644c45b'), 'text': 'Israel', 'label': 'GPE', 'start_char': 5906, 'end_char': 5912}
# {'_id': ObjectId('6543b8ba3392dda60644c45c'), 'text': 'the Mediterranean Sea', 'label': 'LOC', 'start_char': 5917, 'end_char': 5938}
# {'_id': ObjectId('6543b8ba3392dda60644c45d'), 'text': 'Egypt', 'label': 'GPE', 'start_char': 5978, 'end_char': 5983}
# {'_id': ObjectId('6543b8ba3392dda60644c45e'), 'text': 'Just 41km', 'label': 'QUANTITY', 'start_char': 5984, 'end_char': 5993}
# {'_id': ObjectId('6543b8ba3392dda60644c45f'), 'text': '25 miles', 'label': 'QUANTITY', 'start_char': 5995, 'end_char': 6003}
# {'_id': ObjectId('6543b8ba3392dda60644c460'), 'text': '10km', 'label': 'QUANTITY', 'start_char': 6014, 'end_char': 6018}
# {'_id': ObjectId('6543b8ba3392dda60644c461'), 'text': 'more than two million', 'label': 'CARDINAL', 'start_char': 6032, 'end_char': 6053}
# {'_id': ObjectId('6543b8ba3392dda60644c462'), 'text': 'Earth', 'label': 'LOC', 'start_char': 6117, 'end_char': 6122}
# {'_id': ObjectId('6543b8ba3392dda60644c463'), 'text': '1948-49', 'label': 'DATE', 'start_char': 6142, 'end_char': 6149}
# {'_id': ObjectId('6543b8ba3392dda60644c464'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 6155, 'end_char': 6159}
# {'_id': ObjectId('6543b8ba3392dda60644c465'), 'text': 'Egypt', 'label': 'GPE', 'start_char': 6176, 'end_char': 6181}
# {'_id': ObjectId('6543b8ba3392dda60644c466'), 'text': '19 years', 'label': 'DATE', 'start_char': 6186, 'end_char': 6194}
# {'_id': ObjectId('6543b8ba3392dda60644c467'), 'text': 'Israel', 'label': 'GPE', 'start_char': 6195, 'end_char': 6201}
# {'_id': ObjectId('6543b8ba3392dda60644c468'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 6211, 'end_char': 6215}
# {'_id': ObjectId('6543b8ba3392dda60644c469'), 'text': '1967', 'label': 'DATE', 'start_char': 6223, 'end_char': 6227}
# {'_id': ObjectId('6543b8ba3392dda60644c46a'), 'text': '2005', 'label': 'DATE', 'start_char': 6249, 'end_char': 6253}
# {'_id': ObjectId('6543b8ba3392dda60644c46b'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 6281, 'end_char': 6287}
# {'_id': ObjectId('6543b8ba3392dda60644c46c'), 'text': 'Israel', 'label': 'GPE', 'start_char': 6300, 'end_char': 6306}
# {'_id': ObjectId('6543b8ba3392dda60644c46d'), 'text': '2005', 'label': 'DATE', 'start_char': 6343, 'end_char': 6347}
# {'_id': ObjectId('6543b8ba3392dda60644c46e'), 'text': 'UN', 'label': 'ORG', 'start_char': 6428, 'end_char': 6430}
# {'_id': ObjectId('6543b8ba3392dda60644c46f'), 'text': 'Israel', 'label': 'GPE', 'start_char': 6479, 'end_char': 6485}
# {'_id': ObjectId('6543b8ba3392dda60644c470'), 'text': 'the Gaza Strip', 'label': 'GPE', 'start_char': 6495, 'end_char': 6509}
# {'_id': ObjectId('6543b8ba3392dda60644c471'), 'text': 'Gaza Strip', 'label': 'GPE', 'start_char': 6511, 'end_char': 6521}
# {'_id': ObjectId('6543b8ba3392dda60644c472'), 'text': 'Israelis', 'label': 'NORP', 'start_char': 6610, 'end_char': 6618}
# {'_id': ObjectId('6543b8ba3392dda60644c473'), 'text': 'Palestinians?There', 'label': 'PERSON', 'start_char': 6623, 'end_char': 6641}
# {'_id': ObjectId('6543b8ba3392dda60644c474'), 'text': 'two', 'label': 'CARDINAL', 'start_char': 6675, 'end_char': 6678}
# {'_id': ObjectId('6543b8ba3392dda60644c475'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 6739, 'end_char': 6750}
# {'_id': ObjectId('6543b8ba3392dda60644c476'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 6767, 'end_char': 6773}
# {'_id': ObjectId('6543b8ba3392dda60644c477'), 'text': 'West Bank', 'label': 'GPE', 'start_char': 6802, 'end_char': 6811}
# {'_id': ObjectId('6543b8ba3392dda60644c478'), 'text': 'two', 'label': 'CARDINAL', 'start_char': 6849, 'end_char': 6852}
# {'_id': ObjectId('6543b8ba3392dda60644c479'), 'text': 'JerusalemAnd', 'label': 'GPE', 'start_char': 6872, 'end_char': 6884}
# {'_id': ObjectId('6543b8ba3392dda60644c47a'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 6926, 'end_char': 6937}
# {'_id': ObjectId('6543b8ba3392dda60644c47b'), 'text': 'IsraelWhat', 'label': 'ORG', 'start_char': 6972, 'end_char': 6982}
# {'_id': ObjectId('6543b8ba3392dda60644c47c'), 'text': 'problems?Israel', 'label': 'ORG', 'start_char': 7023, 'end_char': 7038}
# {'_id': ObjectId('6543b8ba3392dda60644c47d'), 'text': 'between the 1990s and', 'label': 'DATE', 'start_char': 7084, 'end_char': 7105}
# {'_id': ObjectId('6543b8ba3392dda60644c47e'), 'text': '2010s', 'label': 'DATE', 'start_char': 7106, 'end_char': 7111}
# {'_id': ObjectId('6543b8ba3392dda60644c47f'), 'text': 'the early days', 'label': 'DATE', 'start_char': 7193, 'end_char': 7207}
# {'_id': ObjectId('6543b8ba3392dda60644c480'), 'text': 'Norway', 'label': 'GPE', 'start_char': 7237, 'end_char': 7243}
# {'_id': ObjectId('6543b8ba3392dda60644c481'), 'text': 'Oslo', 'label': 'GPE', 'start_char': 7255, 'end_char': 7259}
# {'_id': ObjectId('6543b8ba3392dda60644c482'), 'text': 'White House', 'label': 'ORG', 'start_char': 7315, 'end_char': 7326}
# {'_id': ObjectId('6543b8ba3392dda60644c483'), 'text': '1993', 'label': 'DATE', 'start_char': 7335, 'end_char': 7339}
# {'_id': ObjectId('6543b8ba3392dda60644c484'), 'text': 'Bill Clinton', 'label': 'PERSON', 'start_char': 7367, 'end_char': 7379}
# {'_id': ObjectId('6543b8ba3392dda60644c485'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 7406, 'end_char': 7418}
# {'_id': ObjectId('6543b8ba3392dda60644c486'), 'text': 'the State of Israel', 'label': 'GPE', 'start_char': 7430, 'end_char': 7449}
# {'_id': ObjectId('6543b8ba3392dda60644c487'), 'text': 'Israel', 'label': 'GPE', 'start_char': 7454, 'end_char': 7460}
# {'_id': ObjectId('6543b8ba3392dda60644c488'), 'text': 'the Palestine Liberation Organisation', 'label': 'ORG', 'start_char': 7494, 'end_char': 7531}
# {'_id': ObjectId('6543b8ba3392dda60644c489'), 'text': 'PLO', 'label': 'ORG', 'start_char': 7533, 'end_char': 7536}
# {'_id': ObjectId('6543b8ba3392dda60644c48a'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 7573, 'end_char': 7584}
# {'_id': ObjectId('6543b8ba3392dda60644c48b'), 'text': 'Palestinian Authority', 'label': 'ORG', 'start_char': 7610, 'end_char': 7631}
# {'_id': ObjectId('6543b8ba3392dda60644c48c'), 'text': 'Benjamin Netanyahu', 'label': 'PERSON', 'start_char': 7701, 'end_char': 7719}
# {'_id': ObjectId('6543b8ba3392dda60644c48d'), 'text': 'Oslo', 'label': 'GPE', 'start_char': 7728, 'end_char': 7732}
# {'_id': ObjectId('6543b8ba3392dda60644c48e'), 'text': 'Israel', 'label': 'GPE', 'start_char': 7752, 'end_char': 7758}
# {'_id': ObjectId('6543b8ba3392dda60644c48f'), 'text': 'Israelis', 'label': 'NORP', 'start_char': 7764, 'end_char': 7772}
# {'_id': ObjectId('6543b8ba3392dda60644c490'), 'text': 'Jews', 'label': 'NORP', 'start_char': 7809, 'end_char': 7813}
# {'_id': ObjectId('6543b8ba3392dda60644c491'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 7830, 'end_char': 7841}
# {'_id': ObjectId('6543b8ba3392dda60644c492'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 7876, 'end_char': 7887}
# {'_id': ObjectId('6543b8ba3392dda60644c493'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 7903, 'end_char': 7908}
# {'_id': ObjectId('6543b8ba3392dda60644c494'), 'text': 'Israel', 'label': 'GPE', 'start_char': 7948, 'end_char': 7954}
# {'_id': ObjectId('6543b8ba3392dda60644c495'), 'text': 'ReutersImage', 'label': 'ORG', 'start_char': 8001, 'end_char': 8013}
# {'_id': ObjectId('6543b8ba3392dda60644c496'), 'text': 'Peace', 'label': 'ORG', 'start_char': 8023, 'end_char': 8028}
# {'_id': ObjectId('6543b8ba3392dda60644c497'), 'text': 'the early 1990s', 'label': 'DATE', 'start_char': 8048, 'end_char': 8063}
# {'_id': ObjectId('6543b8ba3392dda60644c498'), 'text': 'Israel', 'label': 'GPE', 'start_char': 8115, 'end_char': 8121}
# {'_id': ObjectId('6543b8ba3392dda60644c499'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 8150, 'end_char': 8157}
# {'_id': ObjectId('6543b8ba3392dda60644c49a'), 'text': 'Yitzhak Rabin', 'label': 'PERSON', 'start_char': 8173, 'end_char': 8186}
# {'_id': ObjectId('6543b8ba3392dda60644c49b'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 8208, 'end_char': 8214}
# {'_id': ObjectId('6543b8ba3392dda60644c49c'), 'text': '4 November', 'label': 'DATE', 'start_char': 8228, 'end_char': 8238}
# {'_id': ObjectId('6543b8ba3392dda60644c49d'), 'text': 'the 2000s', 'label': 'DATE', 'start_char': 8247, 'end_char': 8256}
# {'_id': ObjectId('6543b8ba3392dda60644c49e'), 'text': '2003', 'label': 'DATE', 'start_char': 8319, 'end_char': 8323}
# {'_id': ObjectId('6543b8ba3392dda60644c49f'), 'text': 'two', 'label': 'CARDINAL', 'start_char': 8395, 'end_char': 8398}
# {'_id': ObjectId('6543b8ba3392dda60644c4a0'), 'text': '2014', 'label': 'DATE', 'start_char': 8480, 'end_char': 8484}
# {'_id': ObjectId('6543b8ba3392dda60644c4a1'), 'text': 'Israelis', 'label': 'NORP', 'start_char': 8516, 'end_char': 8524}
# {'_id': ObjectId('6543b8ba3392dda60644c4a2'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 8529, 'end_char': 8541}
# {'_id': ObjectId('6543b8ba3392dda60644c4a3'), 'text': 'Washington', 'label': 'GPE', 'start_char': 8545, 'end_char': 8555}
# {'_id': ObjectId('6543b8ba3392dda60644c4a4'), 'text': 'US', 'label': 'GPE', 'start_char': 8601, 'end_char': 8603}
# {'_id': ObjectId('6543b8ba3392dda60644c4a5'), 'text': 'Donald Trump', 'label': 'PERSON', 'start_char': 8609, 'end_char': 8621}
# {'_id': ObjectId('6543b8ba3392dda60644c4a6'), 'text': 'the century', 'label': 'DATE', 'start_char': 8662, 'end_char': 8673}
# {'_id': ObjectId('6543b8ba3392dda60644c4a7'), 'text': 'Netanyahu', 'label': 'PERSON', 'start_char': 8693, 'end_char': 8702}
# {'_id': ObjectId('6543b8ba3392dda60644c4a8'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 8729, 'end_char': 8741}
# {'_id': ObjectId('6543b8ba3392dda60644c4a9'), 'text': 'one', 'label': 'CARDINAL', 'start_char': 8745, 'end_char': 8748}
# {'_id': ObjectId('6543b8ba3392dda60644c4aa'), 'text': 'Israel', 'label': 'GPE', 'start_char': 8792, 'end_char': 8798}
# {'_id': ObjectId('6543b8ba3392dda60644c4ab'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 8803, 'end_char': 8807}
# {'_id': ObjectId('6543b8ba3392dda60644c4ac'), 'text': 'now?Image', 'label': 'ORG', 'start_char': 8815, 'end_char': 8824}
# {'_id': ObjectId('6543b8ba3392dda60644c4ad'), 'text': 'Getty ImagesGaza', 'label': 'ORG', 'start_char': 8833, 'end_char': 8849}
# {'_id': ObjectId('6543b8ba3392dda60644c4ae'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 8862, 'end_char': 8867}
# {'_id': ObjectId('6543b8ba3392dda60644c4af'), 'text': 'Islamist', 'label': 'NORP', 'start_char': 8872, 'end_char': 8880}
# {'_id': ObjectId('6543b8ba3392dda60644c4b0'), 'text': 'Israel', 'label': 'GPE', 'start_char': 8928, 'end_char': 8934}
# {'_id': ObjectId('6543b8ba3392dda60644c4b1'), 'text': 'UK', 'label': 'GPE', 'start_char': 8981, 'end_char': 8983}
# {'_id': ObjectId('6543b8ba3392dda60644c4b2'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 9009, 'end_char': 9014}
# {'_id': ObjectId('6543b8ba3392dda60644c4b3'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 9023, 'end_char': 9035}
# {'_id': ObjectId('6543b8ba3392dda60644c4b4'), 'text': '2006', 'label': 'DATE', 'start_char': 9055, 'end_char': 9059}
# {'_id': ObjectId('6543b8ba3392dda60644c4b5'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 9083, 'end_char': 9087}
# {'_id': ObjectId('6543b8ba3392dda60644c4b6'), 'text': 'the following year', 'label': 'DATE', 'start_char': 9088, 'end_char': 9106}
# {'_id': ObjectId('6543b8ba3392dda60644c4b7'), 'text': 'Fatah', 'label': 'ORG', 'start_char': 9128, 'end_char': 9133}
# {'_id': ObjectId('6543b8ba3392dda60644c4b8'), 'text': 'West Bank', 'label': 'GPE', 'start_char': 9146, 'end_char': 9155}
# {'_id': ObjectId('6543b8ba3392dda60644c4b9'), 'text': 'Mahmoud Abbas', 'label': 'PERSON', 'start_char': 9172, 'end_char': 9185}
# {'_id': ObjectId('6543b8ba3392dda60644c4ba'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 9211, 'end_char': 9215}
# {'_id': ObjectId('6543b8ba3392dda60644c4bb'), 'text': 'Israel', 'label': 'GPE', 'start_char': 9246, 'end_char': 9252}
# {'_id': ObjectId('6543b8ba3392dda60644c4bc'), 'text': 'Egypt', 'label': 'GPE', 'start_char': 9271, 'end_char': 9276}
# {'_id': ObjectId('6543b8ba3392dda60644c4bd'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 9335, 'end_char': 9340}
# {'_id': ObjectId('6543b8ba3392dda60644c4be'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 9424, 'end_char': 9431}
# {'_id': ObjectId('6543b8ba3392dda60644c4bf'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 9440, 'end_char': 9452}
# {'_id': ObjectId('6543b8ba3392dda60644c4c0'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 9456, 'end_char': 9460}
# {'_id': ObjectId('6543b8ba3392dda60644c4c1'), 'text': 'Israel', 'label': 'GPE', 'start_char': 9465, 'end_char': 9471}
# {'_id': ObjectId('6543b8ba3392dda60644c4c2'), 'text': 'This year', 'label': 'DATE', 'start_char': 9566, 'end_char': 9575}
# {'_id': ObjectId('6543b8ba3392dda60644c4c3'), 'text': 'the deadliest year', 'label': 'DATE', 'start_char': 9585, 'end_char': 9603}
# {'_id': ObjectId('6543b8ba3392dda60644c4c4'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 9618, 'end_char': 9630}
# {'_id': ObjectId('6543b8ba3392dda60644c4c5'), 'text': 'West Bank', 'label': 'GPE', 'start_char': 9647, 'end_char': 9656}
# {'_id': ObjectId('6543b8ba3392dda60644c4c6'), 'text': 'East Jerusalem', 'label': 'GPE', 'start_char': 9661, 'end_char': 9675}
# {'_id': ObjectId('6543b8ba3392dda60644c4c7'), 'text': 'Israelis', 'label': 'NORP', 'start_char': 9794, 'end_char': 9802}
# {'_id': ObjectId('6543b8ba3392dda60644c4c8'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 9857, 'end_char': 9862}
# {'_id': ObjectId('6543b8ba3392dda60644c4c9'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 9965, 'end_char': 9977}
# {'_id': ObjectId('6543b8ba3392dda60644c4ca'), 'text': 'Israel', 'label': 'GPE', 'start_char': 10019, 'end_char': 10025}
# {'_id': ObjectId('6543b8ba3392dda60644c4cb'), 'text': 'the estimated 4,500', 'label': 'CARDINAL', 'start_char': 10042, 'end_char': 10061}
# {'_id': ObjectId('6543b8ba3392dda60644c4cc'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 10062, 'end_char': 10074}
# {'_id': ObjectId('6543b8ba3392dda60644c4cd'), 'text': 'Israel', 'label': 'GPE', 'start_char': 10108, 'end_char': 10114}
# {'_id': ObjectId('6543b8ba3392dda60644c4ce'), 'text': 'US', 'label': 'GPE', 'start_char': 10161, 'end_char': 10163}
# {'_id': ObjectId('6543b8ba3392dda60644c4cf'), 'text': 'the European Union', 'label': 'ORG', 'start_char': 10165, 'end_char': 10183}
# {'_id': ObjectId('6543b8ba3392dda60644c4d0'), 'text': 'Western', 'label': 'NORP', 'start_char': 10194, 'end_char': 10201}
# {'_id': ObjectId('6543b8ba3392dda60644c4d1'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 10235, 'end_char': 10240}
# {'_id': ObjectId('6543b8ba3392dda60644c4d2'), 'text': 'Israel', 'label': 'GPE', 'start_char': 10251, 'end_char': 10257}
# {'_id': ObjectId('6543b8ba3392dda60644c4d3'), 'text': 'US', 'label': 'GPE', 'start_char': 10262, 'end_char': 10264}
# {'_id': ObjectId('6543b8ba3392dda60644c4d4'), 'text': 'Israel', 'label': 'GPE', 'start_char': 10266, 'end_char': 10272}
# {'_id': ObjectId('6543b8ba3392dda60644c4d5'), 'text': 'the years', 'label': 'DATE', 'start_char': 10298, 'end_char': 10307}
# {'_id': ObjectId('6543b8ba3392dda60644c4d6'), 'text': 'Jewish', 'label': 'NORP', 'start_char': 10318, 'end_char': 10324}
# {'_id': ObjectId('6543b8ba3392dda60644c4d7'), 'text': 'more than $260bn', 'label': 'MONEY', 'start_char': 10331, 'end_char': 10347}
# {'_id': ObjectId('6543b8ba3392dda60644c4d8'), 'text': 'two', 'label': 'CARDINAL', 'start_char': 10485, 'end_char': 10488}
# {'_id': ObjectId('6543b8ba3392dda60644c4d9'), 'text': 'Mediterranean', 'label': 'LOC', 'start_char': 10535, 'end_char': 10548}
# {'_id': ObjectId('6543b8ba3392dda60644c4da'), 'text': 'Israel', 'label': 'GPE', 'start_char': 10558, 'end_char': 10564}
# {'_id': ObjectId('6543b8ba3392dda60644c4db'), 'text': 'Lebanon', 'label': 'GPE', 'start_char': 10589, 'end_char': 10596}
# {'_id': ObjectId('6543b8ba3392dda60644c4dc'), 'text': 'Hezbollah', 'label': 'NORP', 'start_char': 10599, 'end_char': 10608}
# {'_id': ObjectId('6543b8ba3392dda60644c4dd'), 'text': 'second', 'label': 'ORDINAL', 'start_char': 10634, 'end_char': 10640}
# {'_id': ObjectId('6543b8ba3392dda60644c4de'), 'text': 'Russia', 'label': 'GPE', 'start_char': 10658, 'end_char': 10664}
# {'_id': ObjectId('6543b8ba3392dda60644c4df'), 'text': 'China', 'label': 'GPE', 'start_char': 10669, 'end_char': 10674}
# {'_id': ObjectId('6543b8ba3392dda60644c4e0'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 10704, 'end_char': 10709}
# {'_id': ObjectId('6543b8ba3392dda60644c4e1'), 'text': 'Russian', 'label': 'NORP', 'start_char': 10781, 'end_char': 10788}
# {'_id': ObjectId('6543b8ba3392dda60644c4e2'), 'text': 'Vladimir Putin', 'label': 'PERSON', 'start_char': 10799, 'end_char': 10813}
# {'_id': ObjectId('6543b8ba3392dda60644c4e3'), 'text': 'US', 'label': 'GPE', 'start_char': 10825, 'end_char': 10827}
# {'_id': ObjectId('6543b8ba3392dda60644c4e4'), 'text': 'the Middle East', 'label': 'LOC', 'start_char': 10863, 'end_char': 10878}
# {'_id': ObjectId('6543b8ba3392dda60644c4e5'), 'text': 'Iran', 'label': 'GPE', 'start_char': 10879, 'end_char': 10883}
# {'_id': ObjectId('6543b8ba3392dda60644c4e6'), 'text': 'Israel', 'label': 'GPE', 'start_char': 10885, 'end_char': 10891}
# {'_id': ObjectId('6543b8ba3392dda60644c4e7'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 10928, 'end_char': 10933}
# {'_id': ObjectId('6543b8ba3392dda60644c4e8'), 'text': 'Hezbollah', 'label': 'ORG', 'start_char': 10946, 'end_char': 10955}
# {'_id': ObjectId('6543b8ba3392dda60644c4e9'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 11004, 'end_char': 11011}
# {'_id': ObjectId('6543b8ba3392dda60644c4ea'), 'text': 'daily', 'label': 'DATE', 'start_char': 11026, 'end_char': 11031}
# {'_id': ObjectId('6543b8ba3392dda60644c4eb'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 11038, 'end_char': 11043}
# {'_id': ObjectId('6543b8ba3392dda60644c4ec'), 'text': 'Iran', 'label': 'GPE', 'start_char': 11085, 'end_char': 11089}
# {'_id': ObjectId('6543b8ba3392dda60644c4ed'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 11104, 'end_char': 11109}
# {'_id': ObjectId('6543b8ba3392dda60644c4ee'), 'text': 'Tehran', 'label': 'GPE', 'start_char': 11172, 'end_char': 11178}
# {'_id': ObjectId('6543b8ba3392dda60644c4ef'), 'text': 'Israel', 'label': 'GPE', 'start_char': 11224, 'end_char': 11230}
# {'_id': ObjectId('6543b8ba3392dda60644c4f0'), 'text': 'Kibbutz', 'label': 'GPE', 'start_char': 11318, 'end_char': 11325}
# {'_id': ObjectId('6543b8ba3392dda60644c4f1'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 11344, 'end_char': 11348}
# {'_id': ObjectId('6543b8ba3392dda60644c4f2'), 'text': 'Israel', 'label': 'GPE', 'start_char': 11437, 'end_char': 11443}
# {'_id': ObjectId('6543b8ba3392dda60644c4f3'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 11448, 'end_char': 11452}
# {'_id': ObjectId('6543b8ba3392dda60644c4f4'), 'text': 'now?History', 'label': 'ORG', 'start_char': 11462, 'end_char': 11473}
# {'_id': ObjectId('6543b8ba3392dda60644c4f5'), 'text': 'Israel', 'label': 'GPE', 'start_char': 11496, 'end_char': 11502}
# {'_id': ObjectId('6543b8ba3392dda60644c4f6'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 11580, 'end_char': 11584}
# {'_id': ObjectId('6543b8ba3392dda60644c4f7'), 'text': 'storyIsrael', 'label': 'LOC', 'start_char': 11643, 'end_char': 11654}
# {'_id': ObjectId('6543b8ba3392dda60644c4f8'), 'text': 'Israel', 'label': 'GPE', 'start_char': 11718, 'end_char': 11724}
# {'_id': ObjectId('6543b8ba3392dda60644c4f9'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 11810, 'end_char': 11815}
# {'_id': ObjectId('6543b8ba3392dda60644c4fa'), 'text': '9,000', 'label': 'CARDINAL', 'start_char': 11841, 'end_char': 11846}
# {'_id': ObjectId('6543b8ba3392dda60644c4fb'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 11857, 'end_char': 11861}
# {'_id': ObjectId('6543b8ba3392dda60644c4fc'), 'text': '7', 'label': 'CARDINAL', 'start_char': 11868, 'end_char': 11869}
# {'_id': ObjectId('6543b8ba3392dda60644c4fd'), 'text': 'OctoberChinese', 'label': 'WORK_OF_ART', 'start_char': 11870, 'end_char': 11884}
# {'_id': ObjectId('6543b8ba3392dda60644c4fe'), 'text': 'hours', 'label': 'TIME', 'start_char': 11938, 'end_char': 11943}
# {'_id': ObjectId('6543b8ba3392dda60644c4ff'), 'text': 'BBC', 'label': 'ORG', 'start_char': 11971, 'end_char': 11974}
# {'_id': ObjectId('6543b8ba3392dda60644c500'), 'text': 'Chinese', 'label': 'NORP', 'start_char': 11997, 'end_char': 12004}
# {'_id': ObjectId('6543b8ba3392dda60644c501'), 'text': 'hours', 'label': 'TIME', 'start_char': 12022, 'end_char': 12027}
# {'_id': ObjectId('6543b8ba3392dda60644c502'), 'text': 'Bangladesh', 'label': 'GPE', 'start_char': 12121, 'end_char': 12131}
# {'_id': ObjectId('6543b8ba3392dda60644c503'), 'text': "looms'I", 'label': 'ORG', 'start_char': 12144, 'end_char': 12151}
# {'_id': ObjectId('6543b8ba3392dda60644c504'), 'text': '24', 'label': 'CARDINAL', 'start_char': 12175, 'end_char': 12177}
# {'_id': ObjectId('6543b8ba3392dda60644c505'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 12189, 'end_char': 12193}
# {'_id': ObjectId('6543b8ba3392dda60644c506'), 'text': 'BBC', 'label': 'ORG', 'start_char': 12223, 'end_char': 12226}
# {'_id': ObjectId('6543b8ba3392dda60644c507'), 'text': 'Chinese', 'label': 'NORP', 'start_char': 12249, 'end_char': 12256}
# {'_id': ObjectId('6543b8ba3392dda60644c508'), 'text': 'million', 'label': 'CARDINAL', 'start_char': 12301, 'end_char': 12308}
# {'_id': ObjectId('6543b8ba3392dda60644c509'), 'text': 'Trump', 'label': 'GPE', 'start_char': 12318, 'end_char': 12323}
# {'_id': ObjectId('6543b8ba3392dda60644c50a'), 'text': 'US', 'label': 'GPE', 'start_char': 12390, 'end_char': 12392}
# {'_id': ObjectId('6543b8ba3392dda60644c50b'), 'text': 'AI', 'label': 'PRODUCT', 'start_char': 12444, 'end_char': 12446}
# {'_id': ObjectId('6543b8ba3392dda60644c50c'), 'text': 'Europe', 'label': 'LOC', 'start_char': 12491, 'end_char': 12497}
# {'_id': ObjectId('6543b8ba3392dda60644c50d'), 'text': 'tippingEurope', 'label': 'ORG', 'start_char': 12561, 'end_char': 12574}
# {'_id': ObjectId('6543b8ba3392dda60644c50e'), 'text': 'â\x82¬50', 'label': 'ORG', 'start_char': 12589, 'end_char': 12594}
# {'_id': ObjectId('6543b8ba3392dda60644c50f'), 'text': 'British', 'label': 'NORP', 'start_char': 12604, 'end_char': 12611}
# {'_id': ObjectId('6543b8ba3392dda60644c510'), 'text': 'Biden', 'label': 'PERSON', 'start_char': 12709, 'end_char': 12714}
# {'_id': ObjectId('6543b8ba3392dda60644c511'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 12736, 'end_char': 12740}
# {'_id': ObjectId('6543b8ba3392dda60644c512'), 'text': 'BBC', 'label': 'ORG', 'start_char': 12774, 'end_char': 12777}
# {'_id': ObjectId('6543b8ba3392dda60644c513'), 'text': 'Chinese', 'label': 'NORP', 'start_char': 12800, 'end_char': 12807}
# {'_id': ObjectId('6543b8ba3392dda60644c514'), 'text': 'Tomlinson', 'label': 'PERSON', 'start_char': 12822, 'end_char': 12831}
# {'_id': ObjectId('6543b8ba3392dda60644c515'), 'text': '29', 'label': 'DATE', 'start_char': 12833, 'end_char': 12835}
# {'_id': ObjectId('6543b8ba3392dda60644c516'), 'text': "James Corden's", 'label': 'PERSON', 'start_char': 12843, 'end_char': 12857}
# {'_id': ObjectId('6543b8ba3392dda60644c517'), 'text': "' Now", 'label': 'WORK_OF_ART', 'start_char': 12947, 'end_char': 12952}
# {'_id': ObjectId('6543b8ba3392dda60644c518'), 'text': 'kids8Chinese', 'label': 'NORP', 'start_char': 13015, 'end_char': 13027}
# {'_id': ObjectId('6543b8ba3392dda60644c519'), 'text': 'US', 'label': 'GPE', 'start_char': 13081, 'end_char': 13083}
# {'_id': ObjectId('6543b8ba3392dda60644c51a'), 'text': 'names10Offshore', 'label': 'GPE', 'start_char': 13114, 'end_char': 13129}
# {'_id': ObjectId('6543b8ba3392dda60644c51b'), 'text': 'UK', 'label': 'GPE', 'start_char': 13163, 'end_char': 13165}
# {'_id': ObjectId('6543b8ba3392dda60644c51c'), 'text': 'BBC', 'label': 'ORG', 'start_char': 13245, 'end_char': 13248}
# {'_id': ObjectId('6543b8ba3392dda60644c51d'), 'text': 'UseAbout', 'label': 'ORG', 'start_char': 13331, 'end_char': 13339}
# {'_id': ObjectId('6543b8ba3392dda60644c51e'), 'text': 'BBCGet', 'label': 'ORG', 'start_char': 13415, 'end_char': 13421}
# {'_id': ObjectId('6543b8ba3392dda60644c51f'), 'text': 'NewslettersWhy', 'label': 'ORG', 'start_char': 13435, 'end_char': 13449}
# {'_id': ObjectId('6543b8ba3392dda60644c520'), 'text': 'BBCAdvertise', 'label': 'ORG', 'start_char': 13468, 'end_char': 13480}
# {'_id': ObjectId('6543b8ba3392dda60644c521'), 'text': 'usÂ© 2023', 'label': 'DATE', 'start_char': 13486, 'end_char': 13495}
# {'_id': ObjectId('6543b8ba3392dda60644c522'), 'text': 'BBC', 'label': 'ORG', 'start_char': 13496, 'end_char': 13499}
# {'_id': ObjectId('6543b8ba3392dda60644c523'), 'text': 'BBC', 'label': 'ORG', 'start_char': 13505, 'end_char': 13508}
# {'_id': ObjectId('6543b9ca3392dda60644c526'), 'text': 'BBC HomepageSkip', 'label': 'ORG', 'start_char': 0, 'end_char': 16}
# {'_id': ObjectId('6543b9ca3392dda60644c527'), 'text': 'menuSearch', 'label': 'PERSON', 'start_char': 107, 'end_char': 117}
# {'_id': ObjectId('6543b9ca3392dda60644c528'), 'text': 'ArtsHealthWorld News', 'label': 'ORG', 'start_char': 305, 'end_char': 325}
# {'_id': ObjectId('6543b9ca3392dda60644c529'), 'text': 'CanadaIsrael Gaza war History', 'label': 'ORG', 'start_char': 411, 'end_char': 440}
# {'_id': ObjectId('6543b9ca3392dda60644c52a'), 'text': 'agoShareclose panelShare', 'label': 'PERSON', 'start_char': 482, 'end_char': 506}
# {'_id': ObjectId('6543b9ca3392dda60644c52b'), 'text': 'warImage', 'label': 'ORG', 'start_char': 558, 'end_char': 566}
# {'_id': ObjectId('6543b9ca3392dda60644c52c'), 'text': 'Getty ImagesThe', 'label': 'PERSON', 'start_char': 574, 'end_char': 589}
# {'_id': ObjectId('6543b9ca3392dda60644c52d'), 'text': 'Palestinian', 'label': 'NORP', 'start_char': 590, 'end_char': 601}
# {'_id': ObjectId('6543b9ca3392dda60644c52e'), 'text': 'Hamas', 'label': 'ORG', 'start_char': 617, 'end_char': 622}
# {'_id': ObjectId('6543b9ca3392dda60644c52f'), 'text': 'Israel', 'label': 'GPE', 'start_char': 660, 'end_char': 666}
# {'_id': ObjectId('6543b9ca3392dda60644c530'), 'text': '7 October', 'label': 'DATE', 'start_char': 670, 'end_char': 679}
# {'_id': ObjectId('6543b9ca3392dda60644c531'), 'text': 'hundreds', 'label': 'CARDINAL', 'start_char': 685, 'end_char': 693}
# {'_id': ObjectId('6543b9ca3392dda60644c532'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 738, 'end_char': 742}
# {'_id': ObjectId('6543b9ca3392dda60644c533'), 'text': '1400', 'label': 'CARDINAL', 'start_char': 758, 'end_char': 762}
# {'_id': ObjectId('6543b9ca3392dda60644c534'), 'text': 'Israelis', 'label': 'NORP', 'start_char': 763, 'end_char': 771}
# {'_id': ObjectId('6543b9ca3392dda60644c535'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 794, 'end_char': 801}
# {'_id': ObjectId('6543b9ca3392dda60644c536'), 'text': '230', 'label': 'CARDINAL', 'start_char': 816, 'end_char': 819}
# {'_id': ObjectId('6543b9ca3392dda60644c537'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 886, 'end_char': 890}
# {'_id': ObjectId('6543b9ca3392dda60644c538'), 'text': '8000', 'label': 'CARDINAL', 'start_char': 912, 'end_char': 916}
# {'_id': ObjectId('6543b9ca3392dda60644c539'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 917, 'end_char': 929}
# {'_id': ObjectId('6543b9ca3392dda60644c53a'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 933, 'end_char': 937}
# {'_id': ObjectId('6543b9ca3392dda60644c53b'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 1003, 'end_char': 1010}
# {'_id': ObjectId('6543b9ca3392dda60644c53c'), 'text': 'Hamasrun', 'label': 'ORG', 'start_char': 1049, 'end_char': 1057}
# {'_id': ObjectId('6543b9ca3392dda60644c53d'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 1077, 'end_char': 1081}
# {'_id': ObjectId('6543b9ca3392dda60644c53e'), 'text': 'Israeli', 'label': 'NORP', 'start_char': 1082, 'end_char': 1089}
# {'_id': ObjectId('6543b9ca3392dda60644c53f'), 'text': 'Gaza', 'label': 'GPE', 'start_char': 1124, 'end_char': 1128}
# {'_id': ObjectId('6543b9ca3392dda60644c540'), 'text': 'Palestinians', 'label': 'NORP', 'start_char': 1142, 'end_char': 1154}
# {'_id': ObjectId('6543b9ca3392dda60644c541'), 'text': 'Israel', 'label': 'GPE', 'start_char': 1207, 'end_char': 1213}
# ...
# {'_id': ObjectId('6543d31c3392dda60644c9e6'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 7219, 'end_char': 7231}
# {'_id': ObjectId('6543d31c3392dda60644c9e7'), 'text': 'israel', 'label': 'GPE', 'start_char': 7256, 'end_char': 7262}
# {'_id': ObjectId('6543d31c3392dda60644c9e8'), 'text': 'israel', 'label': 'GPE', 'start_char': 7267, 'end_char': 7273}
# {'_id': ObjectId('6543d31c3392dda60644c9e9'), 'text': 'the palestine liberation organisation  ', 'label': 'ORG', 'start_char': 7306, 'end_char': 7345}
# {'_id': ObjectId('6543d31c3392dda60644c9ea'), 'text': 'palestinian', 'label': 'NORP', 'start_char': 7379, 'end_char': 7390}
# {'_id': ObjectId('6543d31c3392dda60644c9eb'), 'text': 'palestinian', 'label': 'NORP', 'start_char': 7414, 'end_char': 7425}
# {'_id': ObjectId('6543d31c3392dda60644c9ec'), 'text': 'benjamin netanyahu', 'label': 'PERSON', 'start_char': 7502, 'end_char': 7520}
# {'_id': ObjectId('6543d31c3392dda60644c9ed'), 'text': 'israel', 'label': 'GPE', 'start_char': 7553, 'end_char': 7559}
# {'_id': ObjectId('6543d31c3392dda60644c9ee'), 'text': 'israelis', 'label': 'NORP', 'start_char': 7564, 'end_char': 7572}
# {'_id': ObjectId('6543d31c3392dda60644c9ef'), 'text': 'jews', 'label': 'NORP', 'start_char': 7609, 'end_char': 7613}
# {'_id': ObjectId('6543d31c3392dda60644c9f0'), 'text': 'palestinian', 'label': 'NORP', 'start_char': 7630, 'end_char': 7641}
# {'_id': ObjectId('6543d31c3392dda60644c9f1'), 'text': 'palestinian', 'label': 'NORP', 'start_char': 7675, 'end_char': 7686}
# {'_id': ObjectId('6543d31c3392dda60644c9f2'), 'text': 'hamas', 'label': 'ORG', 'start_char': 7702, 'end_char': 7707}
# {'_id': ObjectId('6543d31c3392dda60644c9f3'), 'text': 'israel', 'label': 'GPE', 'start_char': 7747, 'end_char': 7753}
# {'_id': ObjectId('6543d31c3392dda60644c9f4'), 'text': 'the early 1990s', 'label': 'DATE', 'start_char': 7844, 'end_char': 7859}
# {'_id': ObjectId('6543d31c3392dda60644c9f5'), 'text': 'the oslo accords', 'label': 'ORG', 'start_char': 7865, 'end_char': 7881}
# {'_id': ObjectId('6543d31c3392dda60644c9f6'), 'text': 'israel', 'label': 'GPE', 'start_char': 7911, 'end_char': 7917}
# {'_id': ObjectId('6543d31c3392dda60644c9f7'), 'text': 'israeli', 'label': 'NORP', 'start_char': 7945, 'end_char': 7952}
# {'_id': ObjectId('6543d31c3392dda60644c9f8'), 'text': 'yitzhak', 'label': 'PERSON', 'start_char': 7968, 'end_char': 7975}
# {'_id': ObjectId('6543d31c3392dda60644c9f9'), 'text': 'jewish', 'label': 'NORP', 'start_char': 8002, 'end_char': 8008}
# {'_id': ObjectId('6543d31c3392dda60644c9fa'), 'text': '4 november 1995', 'label': 'DATE', 'start_char': 8022, 'end_char': 8037}
# {'_id': ObjectId('6543d31c3392dda60644c9fb'), 'text': 'the 2000s', 'label': 'DATE', 'start_char': 8040, 'end_char': 8049}
# {'_id': ObjectId('6543d31c3392dda60644c9fc'), 'text': '2003', 'label': 'DATE', 'start_char': 8111, 'end_char': 8115}
# {'_id': ObjectId('6543d31c3392dda60644c9fd'), 'text': '2014', 'label': 'DATE', 'start_char': 8269, 'end_char': 8273}
# {'_id': ObjectId('6543d31c3392dda60644c9fe'), 'text': 'israelis', 'label': 'NORP', 'start_char': 8304, 'end_char': 8312}
# {'_id': ObjectId('6543d31c3392dda60644c9ff'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 8317, 'end_char': 8329}
# {'_id': ObjectId('6543d31c3392dda60644ca00'), 'text': 'us', 'label': 'GPE', 'start_char': 8387, 'end_char': 8389}
# {'_id': ObjectId('6543d31c3392dda60644ca01'), 'text': 'donald trump', 'label': 'PERSON', 'start_char': 8395, 'end_char': 8407}
# {'_id': ObjectId('6543d31c3392dda60644ca02'), 'text': 'the century', 'label': 'DATE', 'start_char': 8446, 'end_char': 8457}
# {'_id': ObjectId('6543d31c3392dda60644ca03'), 'text': 'netanyahu', 'label': 'PERSON', 'start_char': 8476, 'end_char': 8485}
# {'_id': ObjectId('6543d31c3392dda60644ca04'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 8511, 'end_char': 8523}
# {'_id': ObjectId('6543d31c3392dda60644ca05'), 'text': 'israel', 'label': 'GPE', 'start_char': 8572, 'end_char': 8578}
# {'_id': ObjectId('6543d31c3392dda60644ca06'), 'text': 'gaza', 'label': 'GPE', 'start_char': 8583, 'end_char': 8587}
# {'_id': ObjectId('6543d31c3392dda60644ca07'), 'text': 'hamas', 'label': 'ORG', 'start_char': 8640, 'end_char': 8645}
# {'_id': ObjectId('6543d31c3392dda60644ca08'), 'text': 'islamist', 'label': 'NORP', 'start_char': 8649, 'end_char': 8657}
# {'_id': ObjectId('6543d31c3392dda60644ca09'), 'text': 'israel', 'label': 'GPE', 'start_char': 8705, 'end_char': 8711}
# {'_id': ObjectId('6543d31c3392dda60644ca0a'), 'text': 'uk', 'label': 'GPE', 'start_char': 8758, 'end_char': 8760}
# {'_id': ObjectId('6543d31c3392dda60644ca0b'), 'text': 'countrieshamas', 'label': 'PERSON', 'start_char': 8776, 'end_char': 8790}
# {'_id': ObjectId('6543d31c3392dda60644ca0c'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 8799, 'end_char': 8811}
# {'_id': ObjectId('6543d31c3392dda60644ca0d'), 'text': '2006', 'label': 'DATE', 'start_char': 8830, 'end_char': 8834}
# {'_id': ObjectId('6543d31c3392dda60644ca0e'), 'text': 'gaza', 'label': 'GPE', 'start_char': 8857, 'end_char': 8861}
# {'_id': ObjectId('6543d31c3392dda60644ca0f'), 'text': 'the following year', 'label': 'DATE', 'start_char': 8862, 'end_char': 8880}
# {'_id': ObjectId('6543d31c3392dda60644ca10'), 'text': 'fatah', 'label': 'ORG', 'start_char': 8902, 'end_char': 8907}
# {'_id': ObjectId('6543d31c3392dda60644ca11'), 'text': 'west bankbased', 'label': 'GPE', 'start_char': 8920, 'end_char': 8934}
# {'_id': ObjectId('6543d31c3392dda60644ca12'), 'text': 'mahmoud abbassince', 'label': 'PERSON', 'start_char': 8945, 'end_char': 8963}
# {'_id': ObjectId('6543d31c3392dda60644ca13'), 'text': 'gaza', 'label': 'GPE', 'start_char': 8982, 'end_char': 8986}
# {'_id': ObjectId('6543d31c3392dda60644ca14'), 'text': 'israel', 'label': 'GPE', 'start_char': 9017, 'end_char': 9023}
# {'_id': ObjectId('6543d31c3392dda60644ca15'), 'text': 'egypt', 'label': 'GPE', 'start_char': 9041, 'end_char': 9046}
# {'_id': ObjectId('6543d31c3392dda60644ca16'), 'text': 'hamas', 'label': 'ORG', 'start_char': 9105, 'end_char': 9110}
# {'_id': ObjectId('6543d31c3392dda60644ca17'), 'text': 'israeli', 'label': 'NORP', 'start_char': 9193, 'end_char': 9200}
# {'_id': ObjectId('6543d31c3392dda60644ca18'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 9208, 'end_char': 9220}
# {'_id': ObjectId('6543d31c3392dda60644ca19'), 'text': 'gaza', 'label': 'GPE', 'start_char': 9224, 'end_char': 9228}
# {'_id': ObjectId('6543d31c3392dda60644ca1a'), 'text': 'the deadliest year', 'label': 'DATE', 'start_char': 9351, 'end_char': 9369}
# {'_id': ObjectId('6543d31c3392dda60644ca1b'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 9384, 'end_char': 9396}
# {'_id': ObjectId('6543d31c3392dda60644ca1c'), 'text': 'west bank', 'label': 'GPE', 'start_char': 9413, 'end_char': 9422}
# {'_id': ObjectId('6543d31c3392dda60644ca1d'), 'text': 'east jerusalem', 'label': 'GPE', 'start_char': 9427, 'end_char': 9441}
# {'_id': ObjectId('6543d31c3392dda60644ca1e'), 'text': 'israelisthese', 'label': 'NORP', 'start_char': 9559, 'end_char': 9572}
# {'_id': ObjectId('6543d31c3392dda60644ca1f'), 'text': 'hamass', 'label': 'ORG', 'start_char': 9621, 'end_char': 9627}
# {'_id': ObjectId('6543d31c3392dda60644ca20'), 'text': 'attackbut', 'label': 'ORG', 'start_char': 9635, 'end_char': 9644}
# {'_id': ObjectId('6543d31c3392dda60644ca21'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 9727, 'end_char': 9739}
# {'_id': ObjectId('6543d31c3392dda60644ca22'), 'text': 'israel', 'label': 'GPE', 'start_char': 9780, 'end_char': 9786}
# {'_id': ObjectId('6543d31c3392dda60644ca23'), 'text': 'the estimated 4500', 'label': 'CARDINAL', 'start_char': 9803, 'end_char': 9821}
# {'_id': ObjectId('6543d31c3392dda60644ca24'), 'text': 'palestinians', 'label': 'NORP', 'start_char': 9822, 'end_char': 9834}
# {'_id': ObjectId('6543d31c3392dda60644ca25'), 'text': 'israel', 'label': 'GPE', 'start_char': 9867, 'end_char': 9873}
# {'_id': ObjectId('6543d31c3392dda60644ca26'), 'text': 'the european union', 'label': 'ORG', 'start_char': 9921, 'end_char': 9939}
# {'_id': ObjectId('6543d31c3392dda60644ca27'), 'text': 'hamas', 'label': 'ORG', 'start_char': 9991, 'end_char': 9996}
# {'_id': ObjectId('6543d31c3392dda60644ca28'), 'text': 'the years', 'label': 'DATE', 'start_char': 10050, 'end_char': 10059}
# {'_id': ObjectId('6543d31c3392dda60644ca29'), 'text': 'jewish', 'label': 'NORP', 'start_char': 10070, 'end_char': 10076}
# {'_id': ObjectId('6543d31c3392dda60644ca2a'), 'text': 'two', 'label': 'CARDINAL', 'start_char': 10232, 'end_char': 10235}
# {'_id': ObjectId('6543d31c3392dda60644ca2b'), 'text': 'hezbollah', 'label': 'ORG', 'start_char': 10343, 'end_char': 10352}
# {'_id': ObjectId('6543d31c3392dda60644ca2c'), 'text': 'second', 'label': 'ORDINAL', 'start_char': 10377, 'end_char': 10383}
# {'_id': ObjectId('6543d31c3392dda60644ca2d'), 'text': 'china', 'label': 'GPE', 'start_char': 10411, 'end_char': 10416}
# {'_id': ObjectId('6543d31c3392dda60644ca2e'), 'text': 'hamas', 'label': 'ORG', 'start_char': 10446, 'end_char': 10451}
# {'_id': ObjectId('6543d31c3392dda60644ca2f'), 'text': 'russian', 'label': 'NORP', 'start_char': 10521, 'end_char': 10528}
# {'_id': ObjectId('6543d31c3392dda60644ca30'), 'text': 'vladimir putin', 'label': 'PERSON', 'start_char': 10539, 'end_char': 10553}
# {'_id': ObjectId('6543d31c3392dda60644ca31'), 'text': 'hamas', 'label': 'ORG', 'start_char': 10663, 'end_char': 10668}
# {'_id': ObjectId('6543d31c3392dda60644ca32'), 'text': 'hezbollah', 'label': 'ORG', 'start_char': 10680, 'end_char': 10689}
# {'_id': ObjectId('6543d31c3392dda60644ca33'), 'text': 'israeli', 'label': 'NORP', 'start_char': 10737, 'end_char': 10744}
# {'_id': ObjectId('6543d31c3392dda60644ca34'), 'text': 'almost daily', 'label': 'DATE', 'start_char': 10752, 'end_char': 10764}
# {'_id': ObjectId('6543d31c3392dda60644ca35'), 'text': 'hamass attackquestions', 'label': 'ORG', 'start_char': 10771, 'end_char': 10793}
# {'_id': ObjectId('6543d31c3392dda60644ca36'), 'text': 'irans', 'label': 'NORP', 'start_char': 10816, 'end_char': 10821}
# {'_id': ObjectId('6543d31c3392dda60644ca37'), 'text': 'hamas', 'label': 'ORG', 'start_char': 10834, 'end_char': 10839}
# {'_id': ObjectId('6543d31c3392dda60644ca38'), 'text': 'tehran', 'label': 'GPE', 'start_char': 10898, 'end_char': 10904}
# {'_id': ObjectId('6543d31c3392dda60644ca39'), 'text': 'israelgaza warfollow', 'label': 'ORG', 'start_char': 10947, 'end_char': 10967}
# {'_id': ObjectId('6543d31c3392dda60644ca3a'), 'text': 'gaza', 'label': 'GPE', 'start_char': 11062, 'end_char': 11066}
# {'_id': ObjectId('6543d31c3392dda60644ca3b'), 'text': 'israel', 'label': 'GPE', 'start_char': 11151, 'end_char': 11157}
# {'_id': ObjectId('6543d31c3392dda60644ca3c'), 'text': 'gaza', 'label': 'GPE', 'start_char': 11162, 'end_char': 11166}
# {'_id': ObjectId('6543d31c3392dda60644ca3d'), 'text': 'israelpalestinian', 'label': 'NORP', 'start_char': 11207, 'end_char': 11224}
# {'_id': ObjectId('6543d31c3392dda60644ca3e'), 'text': 'the palestiniansisraelgaza warisraelpalestinian', 'label': 'ORG', 'start_char': 11266, 'end_char': 11313}
# {'_id': ObjectId('6543d31c3392dda60644ca3f'), 'text': 'storyisrael', 'label': 'GPE', 'start_char': 11351, 'end_char': 11362}
# {'_id': ObjectId('6543d31c3392dda60644ca40'), 'text': 'hamaspublished8', 'label': 'ORG', 'start_char': 11393, 'end_char': 11408}
# {'_id': ObjectId('6543d31c3392dda60644ca41'), 'text': 'israel', 'label': 'GPE', 'start_char': 11422, 'end_char': 11428}
# {'_id': ObjectId('6543d31c3392dda60644ca42'), 'text': 'generationpublished7', 'label': 'PERSON', 'start_char': 11468, 'end_char': 11488}
# {'_id': ObjectId('6543d31c3392dda60644ca43'), 'text': 'israel', 'label': 'GPE', 'start_char': 11512, 'end_char': 11518}
# {'_id': ObjectId('6543d31c3392dda60644ca44'), 'text': 'netanyahu', 'label': 'PERSON', 'start_char': 11544, 'end_char': 11553}
# {'_id': ObjectId('6543d31c3392dda60644ca45'), 'text': 'gazachinese', 'label': 'PERSON', 'start_char': 11578, 'end_char': 11589}
# {'_id': ObjectId('6543d31c3392dda60644ca46'), 'text': 'dissentpublished8 hours', 'label': 'LOC', 'start_char': 11624, 'end_char': 11647}
# {'_id': ObjectId('6543d31c3392dda60644ca47'), 'text': 'bbc', 'label': 'ORG', 'start_char': 11675, 'end_char': 11678}
# {'_id': ObjectId('6543d31c3392dda60644ca48'), 'text': 'chinese', 'label': 'NORP', 'start_char': 11701, 'end_char': 11708}
# {'_id': ObjectId('6543d31c3392dda60644ca49'), 'text': 'leaderpublished9', 'label': 'ORG', 'start_char': 11709, 'end_char': 11725}
# {'_id': ObjectId('6543d31c3392dda60644ca4a'), 'text': 'agofeatureschildren', 'label': 'PERSON', 'start_char': 11732, 'end_char': 11751}
# {'_id': ObjectId('6543d31c3392dda60644ca4b'), 'text': 'bangladesh', 'label': 'GPE', 'start_char': 11824, 'end_char': 11834}
# {'_id': ObjectId('6543d31c3392dda60644ca4c'), 'text': '24', 'label': 'CARDINAL', 'start_char': 11874, 'end_char': 11876}
# {'_id': ObjectId('6543d31c3392dda60644ca4d'), 'text': 'gaza', 'label': 'GPE', 'start_char': 11886, 'end_char': 11890}
# {'_id': ObjectId('6543d31c3392dda60644ca4e'), 'text': 'bbc', 'label': 'ORG', 'start_char': 11920, 'end_char': 11923}
# {'_id': ObjectId('6543d31c3392dda60644ca4f'), 'text': 'chinese', 'label': 'NORP', 'start_char': 11946, 'end_char': 11953}
# {'_id': ObjectId('6543d31c3392dda60644ca50'), 'text': 'million', 'label': 'CARDINAL', 'start_char': 11996, 'end_char': 12003}
# {'_id': ObjectId('6543d31c3392dda60644ca51'), 'text': 'liveswhy', 'label': 'PERSON', 'start_char': 12004, 'end_char': 12012}
# {'_id': ObjectId('6543d31c3392dda60644ca52'), 'text': 'mengun', 'label': 'ORG', 'start_char': 12143, 'end_char': 12149}
# {'_id': ObjectId('6543d31c3392dda60644ca53'), 'text': 'europe', 'label': 'LOC', 'start_char': 12181, 'end_char': 12187}
# {'_id': ObjectId('6543d31c3392dda60644ca54'), 'text': '50', 'label': 'CARDINAL', 'start_char': 12277, 'end_char': 12279}
# {'_id': ObjectId('6543d31c3392dda60644ca55'), 'text': 'british', 'label': 'NORP', 'start_char': 12289, 'end_char': 12296}
# {'_id': ObjectId('6543d31c3392dda60644ca56'), 'text': 'names3joe biden', 'label': 'PERSON', 'start_char': 12430, 'end_char': 12445}
# {'_id': ObjectId('6543d31c3392dda60644ca57'), 'text': 'gaza', 'label': 'GPE', 'start_char': 12465, 'end_char': 12469}
# {'_id': ObjectId('6543d31c3392dda60644ca58'), 'text': 'weibo', 'label': 'GPE', 'start_char': 12505, 'end_char': 12510}
# {'_id': ObjectId('6543d31c3392dda60644ca59'), 'text': 'bbc', 'label': 'ORG', 'start_char': 12554, 'end_char': 12557}
# {'_id': ObjectId('6543d31c3392dda60644ca5a'), 'text': 'chinese', 'label': 'NORP', 'start_char': 12580, 'end_char': 12587}
# {'_id': ObjectId('6543d31c3392dda60644ca5b'), 'text': 'tomlinson 29', 'label': 'PERSON', 'start_char': 12602, 'end_char': 12614}
# {'_id': ObjectId('6543d31c3392dda60644ca5c'), 'text': 'james cordens', 'label': 'PERSON', 'start_char': 12621, 'end_char': 12634}
# {'_id': ObjectId('6543d31c3392dda60644ca5d'), 'text': 'kids9chinese', 'label': 'NORP', 'start_char': 12741, 'end_char': 12753}
# {'_id': ObjectId('6543d31c3392dda60644ca5e'), 'text': 'dissent10chinese', 'label': 'NORP', 'start_char': 12788, 'end_char': 12804}
# {'_id': ObjectId('6543d31c3392dda60644ca5f'), 'text': 'argumentbbc news serviceson', 'label': 'ORG', 'start_char': 12842, 'end_char': 12869}
# {'_id': ObjectId('6543d31c3392dda60644ca60'), 'text': 'mobileon smart speakersget news alertscontact', 'label': 'ORG', 'start_char': 12875, 'end_char': 12920}
# {'_id': ObjectId('6543d31c3392dda60644ca61'), 'text': 'bbc', 'label': 'ORG', 'start_char': 12921, 'end_char': 12924}
# {'_id': ObjectId('6543d31c3392dda60644ca62'), 'text': 'bbcget', 'label': 'ORG', 'start_char': 13091, 'end_char': 13097}
# {'_id': ObjectId('6543d31c3392dda60644ca63'), 'text': 'newsletterswhy', 'label': 'ORG', 'start_char': 13111, 'end_char': 13125}
# {'_id': ObjectId('6543d31c3392dda60644ca64'), 'text': '2023', 'label': 'CARDINAL', 'start_char': 13165, 'end_char': 13169}
# {'_id': ObjectId('6543d31c3392dda60644ca65'), 'text': 'bbc', 'label': 'ORG', 'start_char': 13170, 'end_char': 13173}
# {'_id': ObjectId('6543d31c3392dda60644ca66'), 'text': 'bbc', 'label': 'ORG', 'start_char': 13178, 'end_char': 13181}

# %%
# Perform aggregation to count labels
pipeline = [
    {"$group": {"_id": "$label", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
]

result = list(collection.aggregate(pipeline))

# Print the label counts
for doc in result:
    label = doc["_id"]
    count = doc["count"]
    print(f"Label: {label}, Count: {count}")
# Out:
# Label: GPE, Count: 516
# Label: NORP, Count: 396
# Label: ORG, Count: 296
# Label: DATE, Count: 152
# Label: PERSON, Count: 122
# Label: CARDINAL, Count: 112
# Label: LOC, Count: 42
# Label: EVENT, Count: 25
# Label: QUANTITY, Count: 11
# Label: PRODUCT, Count: 10
# Label: TIME, Count: 8
# Label: ORDINAL, Count: 5
# Label: LAW, Count: 5
# Label: WORK_OF_ART, Count: 2
# Label: MONEY, Count: 1
# Label: FAC, Count: 1

# %%
# Close the MongoDB connection
client.close()

# %% [markdown]
# Sentiment Analysis
#
# * Stop words are removed, and lemmatization is applied to the text.
# * Sentiment scores are calculated using the VADER SentimentIntensityAnalyzer on the cleaned text.
# * A sentiment label ("Positive," "Negative," or "Neutral") is determined based on the compound sentiment score.

# %%
# Stop words removal and lemmatization
cleaned_tokens = [token.lemma_ for token in doc if not token.is_stop]

# %%
# Join the cleaned tokens back into a sentence
cleaned_text = " ".join(cleaned_tokens)

# %%
cleaned_tokens
# Out:
# ['bbc',
#  'homepageskip',
#  'contentaccessibility',
#  'helpyour',
#  'accounthomenewssportearthreelworklifetravelmore',
#  'menumore',
#  'menusearch',
#  'bbchomenewssportearthreelworklifetravelculturefuturemusictvweathersoundsclose',
#  'menubbc',
#  'newsmenuhomeisraelgaza',
#  'warwar',
#  'ukraineclimatevideoworldasiaukbusinesstechmorescienceentertainment',
#  ' ',
#  'artshealthworld',
#  'news',
#  'tvin',
#  'picturesbbc',
#  'verifynewsbeatworldafricaaustraliaeuropelatin',
#  'americamiddle',
#  'eastus',
#  ' ',
#  'canadaisrael',
#  'gaza',
#  'war',
#  'history',
#  'conflict',
#  'explainedpublished4',
#  'day',
#  'agoshareclose',
#  'panelshare',
#  'pagecopy',
#  'linkabout',
#  'sharingrelated',
#  'topicsisraelgaza',
#  'warimage',
#  'source',
#  'getty',
#  'imagesthe',
#  'palestinian',
#  'militant',
#  'group',
#  'hama',
#  'launch',
#  'unprecedented',
#  'assault',
#  'israel',
#  '7',
#  'october',
#  'hundred',
#  'gunman',
#  'infiltrate',
#  'community',
#  'near',
#  'gaza',
#  'stripmore',
#  '1400',
#  'israelis',
#  'kill',
#  'israeli',
#  'military',
#  'say',
#  '230',
#  'soldier',
#  'civilian',
#  'include',
#  'woman',
#  'child',
#  'take',
#  'gaza',
#  'hostagesmore',
#  '8000',
#  'palestinians',
#  'gaza',
#  'kill',
#  'air',
#  'artillery',
#  'strike',
#  'carry',
#  'israeli',
#  'military',
#  'response',
#  'accord',
#  'hamasrun',
#  'health',
#  'ministry',
#  'gaza',
#  'israeli',
#  'troop',
#  'mass',
#  'gaza',
#  'boundary',
#  'palestinians',
#  'brace',
#  'major',
#  'ground',
#  'operation',
#  'israel',
#  'cut',
#  'electricity',
#  'water',
#  'stop',
#  'import',
#  'food',
#  'medicine',
#  'allow',
#  'dozen',
#  'aid',
#  'lorry',
#  'egypt',
#  'rafah',
#  'crossing',
#  'saturdaymore',
#  'israelgaza',
#  'warfollow',
#  'live',
#  'late',
#  'updateswatch',
#  'bullet',
#  'hole',
#  'gutte',
#  'room',
#  'inside',
#  'destroy',
#  'kibbutz',
#  'housereporting',
#  'gaza',
#  'camera',
#  'stand',
#  'cryexplaine',
#  'happen',
#  'israel',
#  'gaza',
#  'nowhistory',
#  'story',
#  'israelpalestinian',
#  'conflictwhat',
#  'israel',
#  '1948',
#  'balfour',
#  'declarationbritain',
#  'take',
#  'control',
#  'area',
#  'know',
#  'palestine',
#  'follow',
#  'defeat',
#  'ottoman',
#  'empire',
#  'rule',
#  'middle',
#  'east',
#  'world',
#  'war',
#  'land',
#  'inhabit',
#  'jewish',
#  'minority',
#  'arab',
#  'majority',
#  'small',
#  'ethnic',
#  'group',
#  'tension',
#  'people',
#  'grow',
#  'international',
#  'community',
#  'give',
#  'uk',
#  'task',
#  'establish',
#  'national',
#  'home',
#  'palestine',
#  'jewish',
#  'people',
#  'stem',
#  'balfour',
#  'declaration',
#  '1917',
#  'pledge',
#  'foreign',
#  'secretary',
#  'arthur',
#  'balfour',
#  'britain',
#  'jewish',
#  'communitythe',
#  'declaration',
#  'enshrine',
#  'british',
#  'mandate',
#  'palestine',
#  'endorse',
#  'newlycreate',
#  'league',
#  'nation',
#  ' ',
#  'forerunner',
#  'united',
#  'nations',
#  ' ',
#  '1922to',
#  'jews',
#  'palestine',
#  'ancestral',
#  'home',
#  'palestinian',
#  'arabs',
#  'claim',
#  'land',
#  'oppose',
#  'moveimage',
#  'source',
#  'getty',
#  'imagesimage',
#  'caption',
#  'haganah',
#  ' ',
#  'fighter',
#  'start',
#  'israeli',
#  'war',
#  'independence',
#  '1948between',
#  '1920s',
#  '1940',
#  'number',
#  'jews',
#  'arrive',
#  'grow',
#  'flee',
#  'persecution',
#  'europe',
#  'especially',
#  'nazi',
#  'holocaust',
#  'world',
#  'war',
#  'twoviolence',
#  'jews',
#  'arabs',
#  'british',
#  'rule',
#  'increasedin',
#  '1947',
#  'un',
#  'vote',
#  'palestine',
#  'split',
#  'separate',
#  'jewish',
#  'arab',
#  'state',
#  'jerusalem',
#  'international',
#  'city',
#  'plan',
#  'accept',
#  'jewish',
#  'leader',
#  'reject',
#  'arab',
#  'implementedimage',
#  'source',
#  'getty',
#  'imagesimage',
#  'caption',
#  'soldier',
#  'ally',
#  'arab',
#  'legion',
#  'force',
#  'fire',
#  'fighter',
#  'haganah',
#  'jewish',
#  'agency',
#  'selfdefence',
#  'force',
#  'march',
#  '1948how',
#  'israel',
#  'createdin',
#  '1948',
#  'unable',
#  'solve',
#  'problem',
#  'britain',
#  'withdraw',
#  'jewish',
#  'leader',
#  'declare',
#  'creation',
#  'state',
#  'israelit',
#  'intend',
#  'safe',
#  'haven',
#  'jews',
#  'flee',
#  'persecution',
#  'national',
#  'homeland',
#  'jewsfighte',
#  'jewish',
#  'arab',
#  'militia',
#  'intensify',
#  'month',
#  'day',
#  'israel',
#  'declare',
#  'statehood',
#  'arab',
#  'country',
#  'attackedhundred',
#  'thousand',
#  'palestinians',
#  'flee',
#  'force',
#  'home',
#  'al',
#  'nakba',
#  'catastropheby',
#  'time',
#  'fighting',
#  'end',
#  'ceasefire',
#  'follow',
#  'year',
#  'israel',
#  'control',
#  'territory',
#  'getty',
#  'imagesisrael98',
#  'millionpopulation736jews211arabs53othersource',
#  'israel',
#  'central',
#  'bureau',
#  'statisticsjordan',
#  'occupy',
#  'land',
#  'know',
#  'west',
#  'bank',
#  'egypt',
#  'occupy',
#  'gaza',
#  'jerusalem',
#  'divide',
#  'israeli',
#  'force',
#  'west',
#  'jordanian',
#  'force',
#  'eastbecause',
#  'peace',
#  'agreement',
#  'war',
#  'fighting',
#  'follow',
#  'decadesisrael',
#  'border',
#  'explain',
#  'mapsthe',
#  'map',
#  'israelin',
#  'war',
#  '1967',
#  'israel',
#  'occupy',
#  'east',
#  'jerusalem',
#  'west',
#  'bank',
#  'syrian',
#  'golan',
#  'heights',
#  'gaza',
#  'egyptian',
#  'sinai',
#  'peninsulamost',
#  'palestinian',
#  'refugee',
#  'descendant',
#  'live',
#  'gaza',
#  'west',
#  'bank',
#  'neighbouring',
#  'jordan',
#  'syria',
#  'lebanonneither',
#  'descendant',
#  'allow',
#  'israel',
#  'return',
#  'home',
#  ' ',
#  'israel',
#  'say',
#  'overwhelm',
#  'country',
#  'threaten',
#  'existence',
#  'jewish',
#  'stateimage',
#  'source',
#  'getty',
#  'imagesimage',
#  'caption',
#  'israeli',
#  'military',
#  'commander',
#  'arrive',
#  'east',
#  'jerusalem',
#  'day',
#  'war',
#  '1967israel',
#  'occupy',
#  'west',
#  'bank',
#  'claim',
#  'jerusalem',
#  'capital',
#  'palestinians',
#  'claim',
#  'east',
#  'jerusalem',
#  'capital',
#  'hopedfor',
#  'future',
#  'palestinian',
#  'state',
#  'handful',
#  'country',
#  'recognise',
#  'city',
#  'israels',
#  'capitalin',
#  'past',
#  '50',
#  'year',
#  'israel',
#  'build',
#  'settlement',
#  'west',
#  'bank',
#  'east',
#  'jerusalem',
#  '700000',
#  'jews',
#  'livesettlement',
#  'hold',
#  'illegal',
#  'international',
#  'law',
#  ' ',
#  'position',
#  'un',
#  'security',
#  'council',
#  'uk',
#  'government',
#  ' ',
#  'israel',
#  'reject',
#  'thiswhere',
#  'palestinians',
#  'livegetty',
#  'imagespalestinians143',
#  'milliontotal',
#  'populationwest',
#  'bank3',
#  'milliongaza',
#  'strip2',
#  'millionjordan2',
#  'millionisrael2',
#  'millionsyria05',
#  'millionsource',
#  'palestinian',
#  'central',
#  'bureau',
#  'statisticswhat',
#  'gaza',
#  'stripgaza',
#  'narrow',
#  'strip',
#  'land',
#  'sandwich',
#  'israel',
#  'mediterranean',
#  'sea',
#  'short',
#  'southern',
#  'border',
#  'egyptjust',
#  '41',
#  'km',
#  ' ',
#  'long',
#  '10',
#  'km',
#  'wide',
#  'million',
#  'inhabitant',
#  'densely',
#  'populated',
#  'place',
#  'earthin',
#  'wake',
#  '194849',
#  'war',
#  'gaza',
#  'occupy',
#  'egypt',
#  '19',
#  'yearsisrael',
#  'occupy',
#  'gaza',
#  '1967',
#  'war',
#  'stay',
#  '2005',
#  'time',
#  'build',
#  'jewish',
#  'settlementsisrael',
#  'withdraw',
#  'troop',
#  'settler',
#  '2005',
#  'retain',
#  'control',
#  'airspace',
#  'share',
#  'border',
#  'shoreline',
#  'un',
#  'consider',
#  'territory',
#  'occupy',
#  'israelwhere',
#  'gaza',
#  'strip',
#  'gaza',
#  'strip',
#  'map',
#  'like',
#  'people',
#  'live',
#  'therewhat',
#  'main',
#  'problem',
#  'israelis',
#  'palestiniansthere',
#  'number',
#  'issue',
#  'side',
#  'agree',
#  'include',
#  'happen',
#  'palestinian',
#  'refugeeswhether',
#  'jewish',
#  'settlement',
#  'occupied',
#  'west',
#  'bank',
#  'stay',
#  'removedwhether',
#  'side',
#  'share',
#  'jerusalemand',
#  ' ',
#  'tricky',
#  ' ',
#  'palestinian',
#  'state',
#  'create',
#  'alongside',
#  'israelwhat',
#  'effort',
#  'resolve',
#  'problemsisraelpalestinian',
#  'peace',
#  'talk',
#  'hold',
#  '1990',
#  '2010s',
#  'intersperse',
#  'outbreak',
#  'violencea',
#  'negotiate',
#  'peace',
#  'possible',
#  'early',
#  'day',
#  'series',
#  'secret',
#  'talk',
#  'norway',
#  'oslo',
#  'peace',
#  'process',
#  'forever',
#  'symbolise',
#  'ceremony',
#  'white',
#  'house',
#  'lawn',
#  '1993',
#  'preside',
#  'president',
#  'bill',
#  'clintonin',
#  'historic',
#  'moment',
#  'palestinians',
#  'recognise',
#  'state',
#  'israel',
#  'israel',
#  'recognise',
#  'historical',
#  'enemy',
#  'palestine',
#  'liberation',
#  'organisation',
#  ' ',
#  'sole',
#  'representative',
#  'palestinian',
#  'people',
#  'selfgoverne',
#  'palestinian',
#  'authority',
#  'set',
#  'upcrack',
#  'soon',
#  'appear',
#  'opposition',
#  'leader',
#  'benjamin',
#  'netanyahu',
#  'call',
#  'oslo',
#  'mortal',
#  'threat',
#  'israel',
#  'israelis',
#  'accelerate',
#  'project',
#  'settle',
#  'jews',
#  'occupied',
#  'palestinian',
#  'territory',
#  'recently',
#  'emerge',
#  'palestinian',
#  'militant',
#  'group',
#  'hama',
#  'send',
#  'suicide',
#  'bomber',
#  'kill',
#  'people',
#  'israel',
#  'wreck',
#  'chance',
#  'dealimage',
#  'source',
#  'reutersimage',
#  'caption',
#  'peace',
#  'possible',
#  'early',
#  '1990',
#  'oslo',
#  'accord',
#  'signedthe',
#  'atmosphere',
#  'israel',
#  'turn',
#  'ugly',
#  'culminate',
#  'israeli',
#  'prime',
#  'minister',
#  'yitzhak',
#  'rabin',
#  'assassination',
#  'jewish',
#  'extremist',
#  '4',
#  'november',
#  '1995',
#  '2000s',
#  'attempt',
#  'revive',
#  'peace',
#  'process',
#  ' ',
#  'include',
#  '2003',
#  'roadmap',
#  'devise',
#  'world',
#  'power',
#  'ultimate',
#  'goal',
#  'twostate',
#  'solution',
#  'implement',
#  'peace',
#  'effort',
#  'finally',
#  'stall',
#  '2014',
#  'talk',
#  'fail',
#  'israelis',
#  'palestinians',
#  'washingtonthe',
#  'recent',
#  'peace',
#  'plan',
#  ' ',
#  'prepare',
#  'donald',
#  'trump',
#  'president',
#  ' ',
#  'call',
#  'deal',
#  'century',
#  'prime',
#  'minister',
#  'netanyahu',
#  'dismiss',
#  'palestinians',
#  'oneside',
#  'get',
#  'groundwhy',
#  'israel',
#  'gaza',
#  'war',
#  'nowimage',
#  'source',
#  'getty',
#  'imagesgaza',
#  'rule',
#  'hamas',
#  'islamist',
#  'group',
#  'commit',
#  'destruction',
#  'israel',
#  'designate',
#  'terrorist',
#  'group',
#  'uk',
#  'countrieshamas',
#  'win',
#  'palestinians',
#  'election',
#  '2006',
#  'seize',
#  'control',
#  'gaza',
#  'following',
#  'year',
#  'oust',
#  'rival',
#  'fatah',
#  'movement',
#  'west',
#  'bankbase',
#  'president',
#  'mahmoud',
#  'abbassince',
#  'militant',
#  'gaza',
#  'fight',
#  'war',
#  'israel',
#  'egypt',
#  'maintain',
#  'partial',
#  'blockade',
#  'strip',
#  'isolate',
#  'hama',
#  'try',
#  'stop',
#  'attack',
#  'particularly',
#  'indiscriminate',
#  'firing',
#  'rocket',
#  'israeli',
#  'city',
#  'palestinians',
#  'gaza',
#  'israels',
#  'restriction',
#  'air',
#  'strike',
#  'heavily',
#  'populate',
#  'area',
#  'collective',
#  'punishmentthis',
#  'year',
#  'deadly',
#  'year',
#  'record',
#  'palestinians',
#  'occupied',
#  'west',
#  'bank',
#  'east',
#  'jerusalem',
#  'complain',
#  'restriction',
#  'military',
#  'action',
#  'carry',
#  'response',
#  'deadly',
#  'attack',
#  'israelisthese',
#  'tension',
#  'reason',
#  'hamass',
#  'late',
#  'attackbut',
#  'militant',
#  'seek',
#  'boost',
#  'popularity',
#  'ordinary',
#  'palestinians',
#  'include',
#  'hostage',
#  'pressure',
#  'israel',
#  'free',
#  'estimate',
#  '4500',
#  'palestinians',
#  'hold',
#  'prisonswho',
#  'support',
#  'israel',
#  'current',
#  'conflict',
#  'notthe',
#  'european',
#  'union',
#  'western',
#  'country',
#  'condemn',
#  'hamas',
#  'attack',
#  'israelthe',
#  'israel',
#  'close',
#  'ally',
#  'year',
#  'give',
#  'jewish',
#  'state',
#  '260bn',
#  'military',
#  'economic',
#  'aid',
#  'promise',
#  'additional',
#  'equipment',
#  'air',
#  'defence',
#  'missile',
#  'guide',
#  'bomb',
#  'ammunition',
#  'send',
#  'aircraft',
#  'carrier',
#  'strike',
#  'group',
#  'eastern',
#  'mediterranean',
#  'deter',
#  'israel',
#  'enemy',
#  'particularly',
#  'lebanon',
#  'hezbollah',
#  'movement',
#  'open',
#  'second',
#  'warrussia',
#  'china',
#  'refuse',
#  'condemn',
#  'hama',
#  'maintain',
#  'contact',
#  'side',
#  'conflict',
#  'russian',
#  'president',
#  'vladimir',
#  'putin',
#  'blame',
#  'policy',
#  'absence',
#  'peace',
#  'middle',
#  'eastiran',
#  'israel',
#  'archenemy',
#  'key',
#  'supporter',
#  'hama',
#  'hezbollah',
#  'militant',
#  'exchange',
#  'fire',
#  'israeli',
#  'force',
#  'daily',
#  'hamass',
#  'attackquestions',
#  'ask',
#  'iran',
#  'role',
#  'hamas',
#  'attack',
#  'report',
#  'say',
#  'give',
#  'goahead',
#  'day',
#  'tehran',
#  'deny',
#  'involvementmore',
#  'israelgaza',
#  'warfollow',
#  'live',
#  'late',
#  'updateswatch',
#  'bullet',
#  'hole',
#  'gutte',
#  'room',
#  'inside',
#  'destroy',
#  'kibbutz',
#  'housereporting',
#  'gaza',
#  'camera',
#  'stand',
#  'cryexplaine',
#  'happen',
#  'israel',
#  'gaza',
#  'nowhistory',
#  'story',
#  'israelpalestinian',
#  'conflictrelate',
#  'topicsmiddle',
#  'eastisrael',
#  ' ',
#  'palestiniansisraelgaza',
#  'warisraelpalestinian',
#  'territoriesgazajerusalemmore',
#  'storyisrael',
#  'face',
#  'long',
#  'difficult',
#  'war',
#  'hamaspublished8',
#  'octoberbowen',
#  'israel',
#  'blindside',
#  'attack',
#  'generationpublished7',
#  'octobertop',
#  'storieslive',
#  '\xa0',
#  'israel',
#  'height',
#  'battle',
#  ...]

# %%
# Calculate sentiment scores using VADER on the cleaned text
sentiment_scores = analyzer.polarity_scores(cleaned_text)

# Determine sentiment label based on the compound score
sentiment_label = "Neutral"
if sentiment_scores["compound"] > 0.05:
    sentiment_label = "Positive"
elif sentiment_scores["compound"] < -0.05:
    sentiment_label = "Negative"

# %%
print(sentiment_scores)
# Out:
# {'neg': 0.193, 'neu': 0.711, 'pos': 0.096, 'compound': -0.9992}

# %% [markdown]
# The sentiment analysis for the provided text yields the following sentiment score:
#
# * Negative (neg): 0.193
# * Neutral (neu): 0.711
# * Positive (pos): 0.096
# * Compound: -0.9992
# The compound score is -0.9992, indicating a highly negative sentiment. While the text does contain some neutral and slightly positive elements, the overall sentiment is predominantly negative.

# %% [markdown]
# Future enhancements:
#
# 1. Integration of advanced NLP models for more accurate entity recognition and sentiment analysis.
# 2. Implementation of a more robust data cleaning pipeline to handle complex text structures and diverse content formats.
# 3. Incorporation of a user interface for easier interaction and visualization of the NER and sentiment analysis results.
# 4. Expansion of the database capabilities to handle larger datasets and enable more complex queries and analyses.
